# %%
import unitvelo as utv
import anndata
import scvelo as scv
import numpy as np
import os
import argparse
import time
# Out:
# (Running UniTVelo 0.2.5.2)
# 2023-04-13 17:50:47

# %%
root = "/scratch/blaauw_root/blaauw1/gyichen"
dataset = "IPSC"
adata = anndata.read_h5ad(f"{root}/data/{dataset}_pp.h5ad")

# %%
# Hyperparameters
velo_config = utv.config.Configuration()
velo_config.R2_ADJUST = True
velo_config.IROOT = None
velo_config.FIT_OPTION = '1'
velo_config.ASSIGN_POS_U = True
velo_config.GPU = 0

# %%
t_start = time.time()
label = 'clusters'
adata = utv.run_model(adata, label, config_file=velo_config)
run_time = time.time() - t_start
print(f"Total run time: {run_time}")
# Out:
# ------> Manully Specified Parameters <------
# ASSIGN_POS_U:	True
# ------> Model Configuration Settings <------
# N_TOP_GENES:	2000
# LEARNING_RATE:	0.01
# FIT_OPTION:	1
# DENSITY:	SVD
# REORDER_CELL:	Soft_Reorder
# AGGREGATE_T:	True
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /home/gyichen/velovae/notebooks/UniTVelo.
# Results will be stored in res folder
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# Normalized count data: spliced, unspliced.
# Extracted 2000 highly variable genes.
# WARNING: Did not modify X as it looks preprocessed already.
# Extracted 2000 highly variable genes.
# Computing moments for 2000 genes with n_neighbors: 30 and n_pcs: 30
# computing moments based on connectivities
#     finished (0:00:03) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
#
# # of velocity genes 1513 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 1439 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 1439 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 14266231.105, (Spliced): 13253544.473, (Unspliced): 1012686.632:   7%|▋         | 800/12000 [05:18<1:14:47,  2.50it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 13846844.620, (Spliced): 13232586.274, (Unspliced): 614258.346:  13%|█▎        | 1600/12000 [11:18<1:10:12,  2.47it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 13776172.208, (Spliced): 13230471.383, (Unspliced): 545700.826:  20%|██        | 2400/12000 [17:19<1:05:02,  2.46it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 13750602.452, (Spliced): 13229226.074, (Unspliced): 521376.378:  27%|██▋       | 3200/12000 [23:18<58:54,  2.49it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 13736840.806, (Spliced): 13228470.349, (Unspliced): 508370.457:  33%|███▎      | 4000/12000 [29:16<52:59,  2.52it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 13728397.031, (Spliced): 13228014.921, (Unspliced): 500382.110:  40%|████      | 4800/12000 [35:17<48:16,  2.49it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 13722568.183, (Spliced): 13227653.426, (Unspliced): 494914.757:  47%|████▋     | 5600/12000 [41:16<42:36,  2.50it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 796826.285, (Spliced): 423077.849, (Unspliced): 373748.436:  53%|█████▎    | 6400/12000 [47:23<38:50,  2.40it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 794389.815, (Spliced): 422242.335, (Unspliced): 372147.480:  60%|██████    | 7200/12000 [53:32<32:31,  2.46it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 793093.915, (Spliced): 421504.667, (Unspliced): 371589.248:  67%|██████▋   | 8000/12000 [59:40<27:39,  2.41it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 790076.309, (Spliced): 421388.853, (Unspliced): 368687.455:  73%|███████▎  | 8800/12000 [1:05:48<21:40,  2.46it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 780196.959, (Spliced): 421064.139, (Unspliced): 359132.820:  80%|████████  | 9600/12000 [1:11:59<16:21,  2.45it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 775783.805, (Spliced): 420350.488, (Unspliced): 355433.318:  87%|████████▋ | 10400/12000 [1:18:08<10:51,  2.46it/s]
# Tnn
# A830018L16Rik
# Pm20d1
# Edar
# Gm34113
# Glra1
# Aspa
# Tmem100
# Gm19689
# Dsg3
# Gm4951
# Cd74
# Olfr1316
# Pla2g4e
# Ccdc3
# Syndig1
# Gm26771
# Hmgcs2
# Col25a1
# Car8
# Ntf3
# Cftr
# Gm38947
# A330076H08Rik
# Gm45847
# Ptchd1
# 8030474K03Rik
# Loss (Total): 774248.295, (Spliced): 420587.630, (Unspliced): 353660.664:  93%|█████████▎| 11200/12000 [1:25:27<07:45,  1.72it/s]
# Nabp1
# Pax3
# Mab21l4
# Nfasc
# Hmcn1
# Tnn
# A830018L16Rik
# Pi15
# Crispld1
# Tfap2b
# Il1rl1
# Cxcr2
# Efhd1
# Ramp1
# Serpinb5
# Pm20d1
# Tnnt2
# Ildr2
# H60c
# Edar
# Adamts14
# Srgn
# Phyhipl
# Lgr5
# Nxph4
# Moxd1
# Pkib
# Gm34113
# Rfx4
# Slc5a8
# Kitl
# Itga7
# Myl7
# Nipal4
# Dppa1
# Ltc4s
# Glra1
# Alox12
# Spns2
# Aspa
# Hoxb5os
# Sdk2
# Notum
# Nsg2
# Col23a1
# Atp2a3
# Nos2
# AI662270
# Tmem100
# Dlx3
# Dlx4os
# Axin2
# Gcgr
# Gm46332
# Asb2
# Clmn
# Smoc1
# Batf
# Prl2c2
# Prl8a9
# Rgs7bp
# Col8a2
# Col16a1
# Wnt4
# Spata21
# Zfp985
# Nppb
# Cd36
# Cpz
# Hs3st1
# Rbm47
# Hopx
# Tmprss11e
# Sult1e1
# U90926
# Cxcl10
# Sparcl1
# Dipk1a
# Miat
# Fkbp6
# Col26a1
# Irs3
# Flt1
# Steap4
# Abcb1a
# Lrrc17
# Il6
# Kcnk3
# Ppp2r2c
# Bst1
# Nipal1
# Cwh43
# Pdgfra
# Ereg
# Areg
# Odaph
# Fgf5
# Cds1
# Nos1
# Tbx3
# Pdk4
# Gm20186
# Slc13a4
# Fam180a
# Gprin3
# Chst13
# Alox5
# Gdf3
# Plekhg6
# Ntf3
# Prmt8
# Asb4
# Cftr
# Wnt16
# Cntnap2
# Nfe2l3
# Eva1a
# Tgfa
# Gata2
# Lmcd1
# Pparg
# Tuba8
# Slc6a12
# Tnnt1
# Gm38947
# Psg19
# Psg17
# Apoc1
# Pou2f2
# Mia
# Acp7
# Hamp
# Fxyd1
# Mybpc2
# Myh14
# A330076H08Rik
# Aldh1a3
# Synm
# P2ry6
# Galnt18
# Cpxm2
# Adam12
# Ebf3
# Cdhr5
# Kcnn4
# Kcnc3
# Hrc
# Apba2
# Pcsk6
# Acan
# Alpk3
# Adamtsl3
# Chrdl2
# Olfml1
# Spon1
# Gm45847
# Apobr
# Tnnt3
# Igf2os
# Angpt2
# Zfp42
# Lzts1
# Smpd3
# Cbfa2t3
# 4732419C18Rik
# Fam89a
# Sipa1l2
# Scrg1
# Comp
# Crlf1
# Nwd1
# Gm2694
# Adcy7
# Nkd1
# Adgrg3
# Hsd17b2
# Kcnk1
# Muc16
# Olfm2
# Elavl3
# Acp5
# Adamts15
# Barx2
# Robo3
# Sorl1
# Oaf
# Elovl4
# Snap91
# Zic1
# Acpp
# Slc38a3
# Ccdc13
# Scn3b
# Jaml
# Sema7a
# Stra6
# Calml4
# Igdcc3
# Srpx
# Gm14636
# Usp26
# Gpc3
# Gm28730
# 1700013H16Rik
# Rps6ka6
# Taf7l
# Zmat1
# Nxf7
# Esx1
# Capn6
# Dcx
# Ptchd1
# Tceanc
# Egfl6
# Lonrf3
# Fmr1nb
# AU015836
# Ar
# 8030474K03Rik
# Dmrtc1b
# Srpx2
# Wnk3
# Loss (Total): 719637.593, (Spliced): 402529.890, (Unspliced): 317107.703: 100%|█████████▉| 11999/12000 [1:36:26<00:00,  2.07it/s]
# Total loss 719637.593, vgene loss 719637.593
#   0%|          | 0/26682 [00:00<?, ?cells/s]
# Total run time: 6086.758172035217

# %%
scv.pl.velocity_embedding_stream(adata,
                                 color=adata.uns['label'],
                                 title='',
                                 basis='embed',
                                 legend_loc='far right',
                                 dpi=100)
scv.tl.latent_time(adata, min_likelihood=None)
scv.pl.scatter(adata, color="latent_time", basis='embed', cmap="plasma")
adata.obs['utv_time'] = adata.obs['latent_time'].to_numpy()

adata.uns['utv_run_time'] = run_time

adata.write_h5ad(f'{root}/data/utv/{dataset}/{dataset}.h5ad')
# Out:
# /scratch/blaauw_root/blaauw1/gyichen/utv_env/lib/python3.9/site-packages/scvelo/plotting/utils.py:869: MatplotlibDeprecationWarning: The draw_all function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use fig.draw_without_rendering() instead.
#   cb.draw_all()
