# %%
import unitvelo as utv
import anndata
import scvelo as scv
import numpy as np
import os
import argparse
import time
# Out:
# (Running UniTVelo 0.2.5.2)
# 2023-04-13 17:27:25

# %%
root = "/scratch/blaauw_root/blaauw1/gyichen"
dataset = "Erythroid"
adata = anndata.read_h5ad(f"{root}/data/{dataset}_pp.h5ad")

# %%
# Hyperparameters
velo_config = utv.config.Configuration()
velo_config.R2_ADJUST = True
velo_config.IROOT = None
velo_config.FIT_OPTION = '1'
velo_config.ASSIGN_POS_U = True
velo_config.GPU = 0

# %%
t_start = time.time()
label = 'clusters'
adata = utv.run_model(adata, label, config_file=velo_config)
run_time = time.time() - t_start
print(f"Total run time: {run_time}")
# Out:
# ------> Manully Specified Parameters <------
# ASSIGN_POS_U:	True
# ------> Model Configuration Settings <------
# N_TOP_GENES:	2000
# LEARNING_RATE:	0.01
# FIT_OPTION:	1
# DENSITY:	SVD
# REORDER_CELL:	Soft_Reorder
# AGGREGATE_T:	True
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /home/gyichen/velovae/notebooks/UniTVelo.
# Results will be stored in res folder
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# Normalized count data: spliced, unspliced.
# Skip filtering by dispersion since number of variables are less than `n_top_genes`.
# WARNING: Did not modify X as it looks preprocessed already.
# Extracted 1000 highly variable genes.
# Computing moments for 1000 genes with n_neighbors: 30 and n_pcs: 30
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
#
# # of velocity genes 378 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 375 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 375 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 23639.283, (Spliced): 8763.080, (Unspliced): 14876.203:   7%|▋         | 798/12000 [00:41<09:12, 20.27it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 16107.141, (Spliced): 2324.624, (Unspliced): 13782.517:  13%|█▎        | 1599/12000 [02:36<15:07, 11.46it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 15013.206, (Spliced): 2168.150, (Unspliced): 12845.056:  20%|█▉        | 2399/12000 [03:16<08:15, 19.36it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 14678.057, (Spliced): 2084.921, (Unspliced): 12593.136:  27%|██▋       | 3198/12000 [03:59<07:22, 19.87it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 14635.597, (Spliced): 2081.720, (Unspliced): 12553.877:  33%|███▎      | 4000/12000 [04:42<06:35, 20.25it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 14554.211, (Spliced): 2057.880, (Unspliced): 12496.331:  40%|███▉      | 4798/12000 [05:25<05:57, 20.14it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 14519.217, (Spliced): 2045.155, (Unspliced): 12474.061:  47%|████▋     | 5599/12000 [06:07<05:18, 20.09it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 14388.814, (Spliced): 2106.606, (Unspliced): 12282.208:  53%|█████▎    | 6400/12000 [06:51<04:50, 19.31it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 14326.655, (Spliced): 2096.559, (Unspliced): 12230.096:  60%|█████▉    | 7199/12000 [07:37<04:15, 18.78it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 14285.260, (Spliced): 2090.304, (Unspliced): 12194.956:  67%|██████▋   | 8000/12000 [08:23<03:28, 19.17it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 14286.071, (Spliced): 2098.383, (Unspliced): 12187.688:  73%|███████▎  | 8800/12000 [09:09<02:51, 18.70it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 14314.960, (Spliced): 2136.181, (Unspliced): 12178.779:  80%|████████  | 9600/12000 [09:55<02:06, 19.01it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 14179.404, (Spliced): 2104.075, (Unspliced): 12075.328:  87%|████████▋ | 10400/12000 [10:42<01:24, 18.92it/s]
# Ebf1
# Angpt1
# Gad2
# Nrp1
# Loss (Total): 14452.821, (Spliced): 2369.973, (Unspliced): 12082.848:  93%|█████████▎| 11200/12000 [11:35<00:55, 14.36it/s]
# Pla2g4a
# Elk3
# Timp3
# Igf1
# Plek
# Meis1
# Ebf1
# Angpt1
# Klhl6
# Nrros
# Arhgap31
# Prkcq
# Gad2
# Mpl
# Tie1
# Fxyd5
# Mrvi1
# Nrp1
# Loss (Total): 17181.578, (Spliced): 4706.781, (Unspliced): 12474.797:  93%|█████████▎| 11200/12000 [11:39<00:55, 14.36it/s]
# Pla2g4a
# Elk3
# Timp3
# Igf1
# Plek
# Meis1
# Ebf1
# Angpt1
# Klhl6
# Nrros
# Arhgap31
# Prkcq
# Gad2
# Mpl
# Tie1
# Fxyd5
# Mrvi1
# Nrp1
# Loss (Total): 17181.578, (Spliced): 4706.781, (Unspliced): 12474.797:  93%|█████████▎| 11201/12000 [12:08<00:51, 15.37it/s]
# Total loss 14179.404, vgene loss 17181.578
#   0%|          | 0/9815 [00:00<?, ?cells/s]
# Total run time: 760.216789484024

# %%
scv.pl.velocity_embedding_stream(adata,
                                 color=adata.uns['label'],
                                 title='',
                                 legend_loc='far right',
                                 dpi=100)
scv.tl.latent_time(adata, min_likelihood=None)
scv.pl.scatter(adata, color="latent_time", cmap="plasma")
adata.obs['utv_time'] = adata.obs['latent_time'].to_numpy()

adata.uns['utv_run_time'] = run_time

adata.write_h5ad(f'{root}/data/utv/{dataset}/{dataset}.h5ad')
# Out:
# /scratch/blaauw_root/blaauw1/gyichen/utv_env/lib/python3.9/site-packages/scvelo/plotting/utils.py:869: MatplotlibDeprecationWarning: The draw_all function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use fig.draw_without_rendering() instead.
#   cb.draw_all()
