# %%
import anndata
import scvelo as scv
import numpy as np
from scipy.stats import poisson
from pyrovelocity.api import train_model
from pyrovelocity.plot import plot_posterior_time, plot_gene_ranking,\
      vector_field_uncertainty, plot_vector_field_uncertain,\
      plot_mean_vector_field, project_grid_points,rainbowplot,denoised_umap,\
      us_rainbowplot, plot_arrow_examples
import os
import argparse
import time
import matplotlib.pyplot as plt
import torch
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Discrete Model
# ## 1. Data Preparation

# %%
dataset = 'BMMC'
root = '/scratch/blaauw_root/blaauw1/gyichen'
data_path_base = f'{root}/data'
adata = anndata.read_h5ad(f"{data_path_base}/{dataset}_pp.h5ad")
adata.layers['raw_spliced']   = adata.layers['spliced']
adata.layers['raw_unspliced'] = adata.layers['unspliced']
adata.obs['u_lib_size_raw'] = adata.layers['raw_unspliced'].toarray().sum(-1)
adata.obs['s_lib_size_raw'] = adata.layers['raw_spliced'].toarray().sum(-1)

# %% [markdown]
# ## 2. Train the model with a specific configuration

# %%
num_epochs = 4000
batch_size = -1
likelihood = 'Poisson'
input_type = 'raw'
train_size = 0.7

# %%
t_start = time.time()
pos_train, pos_test, train_idx, test_idx = train_model(adata,
                                                       max_epochs=num_epochs, 
                                                       svi_train=True, 
                                                       log_every=100,
                                                       patient_init=45,
                                                       batch_size=batch_size, 
                                                       use_gpu=0, 
                                                       likelihood=likelihood,
                                                       input_type=input_type,
                                                       cell_state='clusters',
                                                       include_prior=True,
                                                       offset=False,
                                                       library_size=True,
                                                       patient_improve=1e-3,
                                                       seed=2022,
                                                       guide_type='auto_t0_constraint',
                                                       train_size=train_size)
run_time = time.time()-t_start
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["raw_unspliced"]
# INFO     Using data from adata.layers["raw_spliced"]
# INFO     Successfully registered anndata object containing 22122 cells, 2000 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Please do not further modify adata until model is trained.
# Anndata setup with scvi-tools version 0.13.0.
#               Data Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃             Data             ┃ Count ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │            Cells             │ 22122 │
# │             Vars             │ 2000  │
# │            Labels            │   1   │
# │           Batches            │   1   │
# │           Proteins           │   0   │
# │ Extra Categorical Covariates │   0   │
# │ Extra Continuous Covariates  │   0   │
# └──────────────────────────────┴───────┘
#                  SCVI Data Registry
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃       Data       ┃      scvi-tools Location      ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        X         │  adata.layers['raw_spliced']  │
# │        U         │ adata.layers['raw_unspliced'] │
# │      batch       │   adata.obs['_scvi_batch']    │
# │      label       │   adata.obs['_scvi_labels']   │
# │      ind_x       │     adata.obs['_indices']     │
# │    u_lib_size    │    adata.obs['u_lib_size']    │
# │    s_lib_size    │    adata.obs['s_lib_size']    │
# │ u_lib_size_mean  │ adata.obs['u_lib_size_mean']  │
# │ s_lib_size_mean  │ adata.obs['s_lib_size_mean']  │
# │ u_lib_size_scale │ adata.obs['u_lib_size_scale'] │
# │ s_lib_size_scale │ adata.obs['s_lib_size_scale'] │
# └──────────────────┴───────────────────────────────┘
#                         Label Categories
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_labels'] │     0      │          0          │
# └───────────────────────────┴────────────┴─────────────────────┘
#                        Batch Categories
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃     Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_batch'] │     0      │          0          │
# └──────────────────────────┴────────────┴─────────────────────┘
# -----------
# auto
# auto_t0_constraint
# train_faster_with_batch
# step    1 loss = 2.73371e+08 patience = 45
# step  100 loss = 1.7e+08 patience = 45
# step  200 loss = 1.33408e+08 patience = 45
# step  300 loss = 1.09009e+08 patience = 45
# step  400 loss = 8.86829e+07 patience = 45
# step  500 loss = 7.12504e+07 patience = 45
# step  600 loss = 5.71188e+07 patience = 44
# step  700 loss = 4.70707e+07 patience = 44
# step  800 loss = 4.14333e+07 patience = 45
# step  900 loss = 3.87448e+07 patience = 42
# step 1000 loss = 3.73488e+07 patience = 36
# step 1100 loss = 3.65611e+07 patience = 41
# step 1200 loss = 3.62159e+07 patience = 40
# step 1300 loss = 3.60499e+07 patience = 20
# step 1400 loss = 3.59797e+07 patience = 24
# step 1422 loss = 3.5918e+07 patience = 0
# train_faster_with_batch
# step    1 loss = 2.00399e+08 patience = 45
# step  100 loss = 1.5856e+08 patience = 45
# step  200 loss = 1.3306e+08 patience = 45
# step  300 loss = 1.08228e+08 patience = 45
# step  400 loss = 8.63669e+07 patience = 45
# step  500 loss = 6.93979e+07 patience = 45
# step  600 loss = 5.57526e+07 patience = 45
# step  700 loss = 4.62087e+07 patience = 45
# step  800 loss = 4.08404e+07 patience = 45
# step  900 loss = 3.84524e+07 patience = 45
# step 1000 loss = 3.71103e+07 patience = 44
# step 1100 loss = 3.65041e+07 patience = 44
# step 1200 loss = 3.63142e+07 patience = 45
# step 1300 loss = 3.62793e+07 patience = 45
# step 1400 loss = 3.62436e+07 patience = 44
# step 1500 loss = 3.62527e+07 patience = 44
# step 1600 loss = 3.62345e+07 patience = 45
# step 1700 loss = 3.62504e+07 patience = 43
# step 1800 loss = 3.62276e+07 patience = 45
# step 1900 loss = 3.6193e+07 patience = 45
# step 2000 loss = 3.62447e+07 patience = 43
# step 2100 loss = 3.62006e+07 patience = 45
# step 2200 loss = 3.6218e+07 patience = 45
# step 2300 loss = 3.62334e+07 patience = 45
# step 2400 loss = 3.62267e+07 patience = 44
# step 2500 loss = 3.62357e+07 patience = 45
# step 2600 loss = 3.62279e+07 patience = 45
# step 2700 loss = 3.62716e+07 patience = 45
# step 2800 loss = 3.62039e+07 patience = 44
# step 2900 loss = 3.62114e+07 patience = 45
# step 3000 loss = 3.61963e+07 patience = 43
# step 3100 loss = 3.62276e+07 patience = 45
# step 3200 loss = 3.61904e+07 patience = 44
# step 3300 loss = 3.62125e+07 patience = 45
# step 3400 loss = 3.62046e+07 patience = 45
# step 3500 loss = 3.62274e+07 patience = 45
# step 3600 loss = 3.62212e+07 patience = 45
# step 3700 loss = 3.62185e+07 patience = 44
# step 3800 loss = 3.62116e+07 patience = 45
# step 3900 loss = 3.61555e+07 patience = 44
# step 3999 loss = 3.62453e+07 patience = 44

# %% [markdown]
# ## 3. Save intermediate results
# We directly save the results because combining them would take too much memory.

# %%
data_path = f'{data_path_base}/pyro/discrete/{dataset}'
os.makedirs(data_path, exist_ok=True)
for key in pos_train:
    np.save(f'{data_path}/{dataset}_{key}_train.npy', pos_train[key])
del pos_train

# %%
os.makedirs(data_path, exist_ok=True)
for key in pos_test:
    np.save(f'{data_path}/{dataset}_{key}_test.npy', pos_test[key])
del pos_test

# %%
adata.uns['pv_train_idx'] = train_idx
adata.uns['pv_test_idx'] = test_idx
os.makedirs(data_path, exist_ok=True)
adata.write_h5ad(f'{data_path}/{dataset}.h5ad')
del adata

# %% [markdown]
# ## 4. Compute Velocity

# %%
dataset = 'BMMC'
root = '/scratch/blaauw_root/blaauw1/gyichen'
data_path_base = f'{root}/data'
data_path = f'{data_path_base}/pyro/discrete/{dataset}'
adata = anndata.read_h5ad(f'{data_path}/{dataset}.h5ad')

# %%
pos_train, pos_test = {}, {}
keys = ['alpha', 'beta', 'cell_gene_state', 'cell_time', 'dt_switching',
        'gamma', 's_inf', 's', 's_read_depth', 'st_norm', 'st', 'switching',
        't0', 'time_constraint', 'u_inf', 'u', 'u_read_depth', 'ut_norm', 'ut']
for key in keys:
    pos_train[key] = np.load(f'{data_path_base}/pyro/discrete/{dataset}/{dataset}_{key}_train.npy')
    pos_test[key] = np.load(f'{data_path_base}/pyro/discrete/{dataset}/{dataset}_{key}_test.npy')

# %%
train_idx = adata.uns['pv_train_idx']
test_idx = adata.uns['pv_test_idx']

# %%
pos = {}
for key in pos_train:
    n_sample = pos_train[key].shape[0]
    if(pos_train[key].shape[1]>1 and pos_train[key].shape[2]>1):
        val = np.zeros((n_sample, adata.n_obs, adata.n_vars))
        val[:,train_idx] = pos_train[key]
        val[:,test_idx] = pos_test[key]
        pos[key] = val
    elif(pos_train[key].shape[2]==1):
        val = np.zeros((n_sample, adata.n_obs, 1))
        val[:,train_idx] = pos_train[key]
        val[:,test_idx] = pos_test[key]
        pos[key] = val
    else:
        pos[key] = pos_train[key]

# %%
#Compute velocity
embed = "umap"
figure_path = f'{root}/figures/{dataset}'

fig, ax = plt.subplots(figsize=(8, 6))
embed_mean = plot_mean_vector_field(pos,
                                    adata,
                                    ax=ax,
                                    basis=embed,
                                    n_jobs=(adata.n_obs)//2000+1)
# Out:
# computing neighbors
#     finished (0:01:24) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocity graph (using 12/36 cores)
#   0%|          | 0/22122 [00:00<?, ?cells/s]
#     finished (0:05:03) --> added
#     'velocity_pyro_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:04) --> added
#     'velocity_pyro_umap', embedded velocity vectors (adata.obsm)

# %% [markdown]
# ## 5. Compute performance metrics and save results

# %%
def save_fitting(adata, pos_train, train_idx, pos_test=None, test_idx=None):
    split = not ((pos_test is None) or (test_idx is None))
    for key in pos_train:
        k,m,n = pos_train[key].shape
        if(m>1 and n>1):
            adata.layers[f'pv_{key}'] = np.zeros((adata.n_obs,n))
            adata.layers[f'pv_{key}'][train_idx] = pos_train[key].mean(0)
            if(split):
                adata.layers[f'pv_{key}'][test_idx] = pos_test[key].mean(0)
        elif(m>1):
            adata.obs[f'pv_{key}'] = np.zeros((adata.n_obs))
            adata.obs[f'pv_{key}'][train_idx] = pos_train[key].mean(0).squeeze()
            if(split):
                adata.obs[f'pv_{key}'][test_idx] = pos_test[key].mean(0).squeeze()
        elif(n>1):
            adata.var[f'pv_{key}'] = pos_train[key].mean(0).squeeze()
        else:
            adata.uns[f'pv_{key}'] = pos_train[key]

# %%
embed = 'umap'
adata.obsm[f"pv_velocity_{embed}"] = embed_mean
del adata.obsm[f"velocity_pyro_{embed}"]
adata.layers["pv_shat"] = adata.layers["spliced_pyro"]
adata.layers["pv_uhat"] = np.zeros(adata.shape)
adata.layers["pv_uhat"][train_idx] = pos_train["u"].mean(0)
adata.layers["pv_uhat"][test_idx] = pos_test["u"].mean(0)
del adata.layers["spliced_pyro"]
adata.layers["pv_velocity"] = adata.layers["velocity_pyro"]
del adata.layers["velocity_pyro"]

adata.obs['pv_time'] = pos['cell_time'][:,:,0].mean(0).squeeze()
adata.uns['pv_train_idx'] = train_idx
adata.uns['pv_test_idx'] = test_idx
save_fitting(adata, pos_train, train_idx, pos_test, test_idx)

err_dic = {}
mse_train, mse_test, mae_train, mae_test, logp_train, logp_test = 0,0,0,0,0,0
mse_train_gene = np.ones((adata.n_vars))*np.nan
mse_test_gene = np.ones((adata.n_vars))*np.nan
mae_train_gene = np.ones((adata.n_vars))*np.nan
mae_test_gene = np.ones((adata.n_vars))*np.nan
ll_train_gene = np.ones((adata.n_vars))*np.nan
ll_test_gene = np.ones((adata.n_vars))*np.nan
for i in range(n_sample):
    dist_u_train = np.abs(adata.layers['raw_unspliced'][train_idx].A-pos_train['u'][i])
    dist_s_train = np.abs(adata.layers['raw_spliced'][train_idx].A-pos_train['s'][i])
    dist_u_test = np.abs(adata.layers['raw_unspliced'][test_idx].A-pos_test['u'][i])
    dist_s_test = np.abs(adata.layers['raw_spliced'][test_idx].A-pos_test['s'][i])
    mse_train += np.mean(dist_u_train**2+dist_s_train**2)
    mse_test += np.mean(dist_u_test**2+dist_s_test**2)
    mae_train += np.mean(dist_u_train+dist_s_train)
    mae_test += np.mean(dist_u_test+dist_s_test)
    logp_train += np.log(poisson.pmf(adata.layers['raw_unspliced'][train_idx].A, pos_train['ut'][i])+1e-10).sum(1).mean()\
                 +np.log(poisson.pmf(adata.layers['raw_spliced'][train_idx].A, pos_train['st'][i])+1e-10).sum(1).mean()
    logp_test += np.log(poisson.pmf(adata.layers['raw_unspliced'][test_idx].A, pos_test['ut'][i])+1e-10).sum(1).mean()\
                 +np.log(poisson.pmf(adata.layers['raw_spliced'][test_idx].A, pos_test['st'][i])+1e-10).sum(1).mean()
    mse_train_gene = mse_train_gene + np.mean(dist_u_train**2+dist_s_train**2, 0)
    mse_test_gene = mse_test_gene + np.mean(dist_u_test**2+dist_s_test**2, 0)
    mae_train_gene = mae_train_gene + np.mean(dist_u_train+dist_s_train, 0)
    mae_test_gene = mae_test_gene + np.mean(dist_u_test+dist_s_test, 0)
    ll_train_gene = ll_train_gene\
                  + np.log(poisson.pmf(adata.layers['raw_unspliced'][train_idx].A, pos_train['ut'][i])+1e-10).mean(0)\
                  + np.log(poisson.pmf(adata.layers['raw_spliced'][train_idx].A, pos_train['st'][i])+1e-10).mean(0)
    ll_test_gene = ll_test_gene\
                 + np.log(poisson.pmf(adata.layers['raw_unspliced'][test_idx].A, pos_test['ut'][i])+1e-10).mean(0)\
                 + np.log(poisson.pmf(adata.layers['raw_spliced'][test_idx].A, pos_test['st'][i])+1e-10).mean(0)

# %%
adata.var['pv_mse_train'] = mse_train_gene / n_sample
adata.var['pv_mse_test'] = mse_test_gene / n_sample
adata.var['pv_mae_train'] = mae_train_gene / n_sample
adata.var['pv_mae_test'] = mae_test_gene / n_sample
adata.var['pv_likelihood_train'] = ll_train_gene / n_sample
adata.var['pv_likelihood_test'] = ll_test_gene / n_sample
err_dic['MSE Train'] = mse_train / n_sample
err_dic['MSE Test'] = mse_test / n_sample
err_dic['MAE Train'] = mae_train / n_sample
err_dic['MAE Test'] = mae_test / n_sample
err_dic['LL Train'] = logp_train / n_sample
err_dic['LL Test'] = logp_test / n_sample
adata.uns['err'] = err_dic

# %%
err_dic
# Out:
# {'MSE Train': 13.86285628027123,
#  'MSE Test': 14.40226010245593,
#  'MAE Train': 0.471558340329351,
#  'MAE Test': 0.47799224549244135,
#  'LL Train': -1817.014790139078,
#  'LL Test': -1818.0974463046343}

# %% [markdown]
# ## Write to disk and plot results

# %%
data_path = f'{data_path_base}/pyro/discrete/{dataset}'
os.makedirs(data_path, exist_ok=True)
adata.write_h5ad(f'{data_path}/{dataset}.h5ad')

# %%
from pyrovelocity.utils import mae_evaluate
out = mae_evaluate((pos_train, pos_test, train_idx, test_idx), adata)
# Out:
#                     MAE
# label
# Poisson train  0.235779
# Poisson valid  0.238996

# %%
scv.pl.velocity_embedding_stream(adata,
                                 basis=embed,
                                 title='',
                                 vkey='pv_velocity',
                                 dpi=120,
                                 save=f'{figure_path}/pv_vel_stream.png')
# Out:
# saving figure to file /scratch/blaauw_root/blaauw1/gyichen/figures/BMMC/pv_vel_stream.png

# %%
scv.pl.scatter(adata, basis=embed, color='pv_time', color_map='plasma', dpi=100, save=f'{figure_path}/pv_time.png')
# Out:
# saving figure to file /scratch/blaauw_root/blaauw1/gyichen/figures/BMMC/pv_time.png

# %%
del adata
del pos
del pos_train
del pos_test

# %% [markdown]
# # Continuous Model
# ## 1. Prepare Data

# %%
dataset = 'BMMC'
root = '/scratch/blaauw_root/blaauw1/gyichen'
data_path_base = f'{root}/data'
adata = anndata.read_h5ad(f"{data_path_base}/{dataset}_pp.h5ad")

# %% [markdown]
# ## 2. Train the model with a specific configuration

# %%
num_epochs = 4000
batch_size = -1
likelihood = 'Normal'
input_type = 'knn'
train_size = 0.7

# %%
t_start = time.time()
pos_train, pos_test, train_idx, test_idx = train_model(adata,
                                                       max_epochs=num_epochs, 
                                                       svi_train=True, 
                                                       log_every=100,
                                                       patient_init=45,
                                                       batch_size=batch_size, 
                                                       use_gpu=0, 
                                                       likelihood=likelihood,
                                                       input_type=input_type,
                                                       cell_state='clusters',
                                                       include_prior=True,
                                                       offset=False,
                                                       library_size=True,
                                                       patient_improve=1e-3,
                                                       seed=2022,
                                                       guide_type='auto_t0_constraint',
                                                       train_size=train_size)
run_time = time.time()-t_start
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO:scvi.data._anndata:No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO:scvi.data._anndata:No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["Mu"]
# INFO:scvi.data._anndata:Using data from adata.layers["Mu"]
# INFO     Using data from adata.layers["Ms"]
# INFO:scvi.data._anndata:Using data from adata.layers["Ms"]
# INFO     Successfully registered anndata object containing 22122 cells, 2000 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO:scvi.data._anndata:Successfully registered anndata object containing 22122 cells, 2000 vars, 1 batches, 1 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Please do not further modify adata until model is trained.
# INFO:scvi.data._anndata:Please do not further modify adata until model is trained.
# Anndata setup with scvi-tools version 0.13.0.
#               Data Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃             Data             ┃ Count ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │            Cells             │ 22122 │
# │             Vars             │ 2000  │
# │            Labels            │   1   │
# │           Batches            │   1   │
# │           Proteins           │   0   │
# │ Extra Categorical Covariates │   0   │
# │ Extra Continuous Covariates  │   0   │
# └──────────────────────────────┴───────┘
#                  SCVI Data Registry
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃       Data       ┃      scvi-tools Location      ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        X         │      adata.layers['Ms']       │
# │        U         │      adata.layers['Mu']       │
# │      batch       │   adata.obs['_scvi_batch']    │
# │      label       │   adata.obs['_scvi_labels']   │
# │      ind_x       │     adata.obs['_indices']     │
# │    u_lib_size    │    adata.obs['u_lib_size']    │
# │    s_lib_size    │    adata.obs['s_lib_size']    │
# │ u_lib_size_mean  │ adata.obs['u_lib_size_mean']  │
# │ s_lib_size_mean  │ adata.obs['s_lib_size_mean']  │
# │ u_lib_size_scale │ adata.obs['u_lib_size_scale'] │
# │ s_lib_size_scale │ adata.obs['s_lib_size_scale'] │
# └──────────────────┴───────────────────────────────┘
#                         Label Categories
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_labels'] │     0      │          0          │
# └───────────────────────────┴────────────┴─────────────────────┘
#                        Batch Categories
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃     Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_batch'] │     0      │          0          │
# └──────────────────────────┴────────────┴─────────────────────┘
# -----------
# auto
# auto_t0_constraint
# train_faster_with_batch
# step    1 loss = 4.07979e+08 patience = 45
# step  100 loss = 6.00762e+07 patience = 45
# step  200 loss = -3.63182e+07 patience = 44
# step  300 loss = -7.77967e+07 patience = 45
# step  400 loss = -9.77429e+07 patience = 45
# step  500 loss = -1.04768e+08 patience = 45
# step  600 loss = -1.08291e+08 patience = 45
# step  700 loss = -1.08738e+08 patience = 43
# step  800 loss = -1.10715e+08 patience = 45
# step  900 loss = -1.09941e+08 patience = 45
# step 1000 loss = -1.11871e+08 patience = 45
# step 1100 loss = -1.12504e+08 patience = 44
# step 1200 loss = -1.13771e+08 patience = 45
# step 1300 loss = -1.14746e+08 patience = 45
# step 1400 loss = -1.15743e+08 patience = 45
# step 1500 loss = -1.16784e+08 patience = 45
# step 1600 loss = -1.17494e+08 patience = 45
# step 1700 loss = -1.18078e+08 patience = 45
# step 1800 loss = -1.18458e+08 patience = 45
# step 1900 loss = -1.18756e+08 patience = 45
# step 2000 loss = -1.19161e+08 patience = 45
# step 2100 loss = -1.19378e+08 patience = 45
# step 2200 loss = -1.19652e+08 patience = 45
# step 2300 loss = -1.19807e+08 patience = 45
# step 2400 loss = -1.19989e+08 patience = 45
# step 2500 loss = -1.20103e+08 patience = 45
# step 2600 loss = -1.20273e+08 patience = 45
# step 2700 loss = -1.20447e+08 patience = 45
# step 2800 loss = -1.20678e+08 patience = 45
# step 2900 loss = -1.20744e+08 patience = 45
# step 3000 loss = -1.21022e+08 patience = 45
# step 3100 loss = -1.21169e+08 patience = 45
# step 3200 loss = -1.2128e+08 patience = 45
# step 3300 loss = -1.21441e+08 patience = 45
# step 3400 loss = -1.2161e+08 patience = 45
# step 3500 loss = -1.21602e+08 patience = 45
# step 3600 loss = -1.21709e+08 patience = 45
# step 3700 loss = -1.21677e+08 patience = 45
# step 3800 loss = -1.21713e+08 patience = 45
# step 3900 loss = -1.21699e+08 patience = 45
# step 3999 loss = -1.21736e+08 patience = 45
# train_faster_with_batch
# step    1 loss = -1.01966e+08 patience = 45
# step  100 loss = -1.04717e+08 patience = 45
# step  200 loss = -1.17855e+08 patience = 45
# step  300 loss = -1.21723e+08 patience = 45
# step  400 loss = -1.21872e+08 patience = 44
# step  500 loss = -1.21892e+08 patience = 45
# step  600 loss = -1.21827e+08 patience = 41
# step  700 loss = -1.21858e+08 patience = 43
# step  800 loss = -1.21842e+08 patience = 45
# step  900 loss = -1.21819e+08 patience = 43
# step 1000 loss = -1.21805e+08 patience = 44
# step 1100 loss = -1.21821e+08 patience = 45
# step 1200 loss = -1.21846e+08 patience = 45
# step 1300 loss = -1.21798e+08 patience = 44
# step 1400 loss = -1.21837e+08 patience = 45
# step 1500 loss = -1.21833e+08 patience = 45
# step 1600 loss = -1.21827e+08 patience = 44
# step 1700 loss = -1.21848e+08 patience = 44
# step 1800 loss = -1.21823e+08 patience = 44
# step 1900 loss = -1.21818e+08 patience = 45
# step 2000 loss = -1.21852e+08 patience = 44
# step 2100 loss = -1.2186e+08 patience = 44
# step 2200 loss = -1.21865e+08 patience = 45
# step 2300 loss = -1.2178e+08 patience = 45
# step 2400 loss = -1.21875e+08 patience = 44
# step 2500 loss = -1.2185e+08 patience = 45
# step 2600 loss = -1.21825e+08 patience = 45
# step 2700 loss = -1.21832e+08 patience = 45
# step 2800 loss = -1.21842e+08 patience = 44
# step 2900 loss = -1.21861e+08 patience = 45
# step 3000 loss = -1.21817e+08 patience = 44
# step 3100 loss = -1.21852e+08 patience = 44
# step 3200 loss = -1.2184e+08 patience = 44
# step 3300 loss = -1.21819e+08 patience = 43
# step 3400 loss = -1.21782e+08 patience = 42
# step 3500 loss = -1.21863e+08 patience = 44
# step 3600 loss = -1.2188e+08 patience = 43
# step 3700 loss = -1.21808e+08 patience = 44
# step 3800 loss = -1.21796e+08 patience = 44
# step 3900 loss = -1.21839e+08 patience = 45
# step 3999 loss = -1.21765e+08 patience = 43

# %% [markdown]
# ## 3. Save intermediate results

# %%
data_path = f'{data_path_base}/pyro/continuous/{dataset}'
os.makedirs(data_path, exist_ok=True)
for key in pos_train:
    np.save(f'{data_path}/{dataset}_{key}_train.npy', pos_train[key])
del pos_train

# %%
os.makedirs(data_path, exist_ok=True)
for key in pos_test:
    np.save(f'{data_path}/{dataset}_{key}_test.npy', pos_test[key])
del pos_test

# %%
adata.uns['pv_train_idx'] = train_idx
adata.uns['pv_test_idx'] = test_idx
os.makedirs(data_path, exist_ok=True)
adata.write_h5ad(f'{data_path}/{dataset}.h5ad')
del adata

# %% [markdown]
# ## 4. Compute Velocity

# %%
dataset = 'BMMC'
root = '/scratch/blaauw_root/blaauw1/gyichen'
data_path_base = f'{root}/data'
data_path = f'{data_path_base}/pyro/continuous/{dataset}'
adata = anndata.read_h5ad(f'{data_path}/{dataset}.h5ad')

# %%
pos_train, pos_test = {}, {}
keys = ['alpha', 'beta', 'cell_gene_state', 'cell_time', 'dt_switching',
        'gamma', 's_inf', 's_scale', 's', 'switching',
        't0', 'time_constraint', 'u_inf', 'u_scale', 'u']
for key in keys:
    pos_train[key] = np.load(f'{data_path_base}/pyro/continuous/{dataset}/{dataset}_{key}_train.npy')
    pos_test[key] = np.load(f'{data_path_base}/pyro/continuous/{dataset}/{dataset}_{key}_test.npy')

# %%
train_idx = adata.uns['pv_train_idx']
test_idx = adata.uns['pv_test_idx']
pos = {}
for key in pos_train:
    n_sample = pos_train[key].shape[0]
    if(pos_train[key].shape[1]>1 and pos_train[key].shape[2]>1):
        val = np.zeros((n_sample, adata.n_obs, adata.n_vars))
        val[:,train_idx] = pos_train[key]
        val[:,test_idx] = pos_test[key]
        pos[key] = val
    elif(pos_train[key].shape[2]==1):
        val = np.zeros((n_sample, adata.n_obs, 1))
        val[:,train_idx] = pos_train[key]
        val[:,test_idx] = pos_test[key]
        pos[key] = val
    else:
        pos[key] = pos_train[key]
pos['ut'] = pos['u'] * pos["u_scale"]
pos['st'] = pos['s']

# %%
#Compute velocity
embed = "umap"
figure_path = f'{root}/figures/{dataset}'

fig, ax = plt.subplots(figsize=(8, 6))
embed_mean = plot_mean_vector_field(pos,
                                    adata,
                                    ax=ax,
                                    basis=embed,
                                    n_jobs=(adata.n_obs)//2000+1)
# Out:
# computing neighbors
#     finished (0:00:20) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocity graph (using 12/36 cores)
#   0%|          | 0/22122 [00:00<?, ?cells/s]
#     finished (0:01:31) --> added
#     'velocity_pyro_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:04) --> added
#     'velocity_pyro_umap', embedded velocity vectors (adata.obsm)

# %% [markdown]
# ## 5. Compute performance metrics and save results

# %%
def save_fitting(adata, pos_train, train_idx, pos_test=None, test_idx=None):
    split = not ((pos_test is None) or (test_idx is None))
    for key in pos_train:
        k,m,n = pos_train[key].shape
        if(m>1 and n>1):
            adata.layers[f'pv_{key}'] = np.zeros((adata.n_obs,n))
            adata.layers[f'pv_{key}'][train_idx] = pos_train[key].mean(0)
            if(split):
                adata.layers[f'pv_{key}'][test_idx] = pos_test[key].mean(0)
        elif(m>1):
            adata.obs[f'pv_{key}'] = np.zeros((adata.n_obs))
            adata.obs[f'pv_{key}'][train_idx] = pos_train[key].mean(0).squeeze()
            if(split):
                adata.obs[f'pv_{key}'][test_idx] = pos_test[key].mean(0).squeeze()
        elif(n>1):
            adata.var[f'pv_{key}'] = pos_train[key].mean(0).squeeze()
        else:
            adata.uns[f'pv_{key}'] = pos_train[key]

# %%
adata.obsm[f"pv_velocity_{embed}"] = embed_mean
del adata.obsm[f"velocity_pyro_{embed}"]
adata.layers["pv_shat"] = adata.layers["spliced_pyro"]
adata.layers["pv_uhat"] = np.zeros(adata.shape)
adata.layers["pv_uhat"][train_idx] = pos_train["u"].mean(0)
adata.layers["pv_uhat"][test_idx] = pos_test["u"].mean(0)
del adata.layers["spliced_pyro"]
adata.layers["pv_velocity"] = adata.layers["velocity_pyro"]
del adata.layers["velocity_pyro"]

adata.obs['pv_time'] = pos['cell_time'][:,:,0].mean(0).squeeze()
adata.uns['pv_train_idx'] = train_idx
adata.uns['pv_test_idx'] = test_idx
save_fitting(adata, pos_train, train_idx, pos_test, test_idx)

err_dic = {}
mse_train, mse_test, mae_train, mae_test, logp_train, logp_test = 0,0,0,0,0,0
mse_train_gene = np.ones((adata.n_vars))*np.nan
mse_test_gene = np.ones((adata.n_vars))*np.nan
mae_train_gene = np.ones((adata.n_vars))*np.nan
mae_test_gene = np.ones((adata.n_vars))*np.nan
ll_train_gene = np.ones((adata.n_vars))*np.nan
ll_test_gene = np.ones((adata.n_vars))*np.nan
for i in range(pos['u'].shape[0]):
    dist_u_train = np.abs(adata.layers['Mu'][train_idx]-pos_train['u'][i])
    dist_s_train = np.abs(adata.layers['Ms'][train_idx]-pos_train['s'][i])
    dist_u_test = np.abs(adata.layers['Mu'][test_idx]-pos_test['u'][i])
    dist_s_test = np.abs(adata.layers['Ms'][test_idx]-pos_test['s'][i])
    mse_train += np.mean(dist_u_train**2+dist_s_train**2)
    mse_test += np.mean(dist_u_test**2+dist_s_test**2)
    mae_train += np.mean(dist_u_train+dist_s_train)
    mae_test += np.mean(dist_u_test+dist_s_test)
    #MLE of variance
    var_s_train, var_s_test = np.var(adata.layers['Mu'][train_idx]-pos_train['u'][i],0),np.var(adata.layers['Ms'][train_idx]-pos_train['s'][i],0)
    var_u_train, var_u_test = np.var(adata.layers['Mu'][test_idx]-pos_test['u'][i],0),np.var(adata.layers['Ms'][test_idx]-pos_test['s'][i],0)
    logp_train_mtx = -dist_u_train**2/(2*var_u_train)-dist_s_train**2/(2*var_s_train) \
                  - 0.5*np.log(var_u_train) - 0.5*np.log(var_s_train) - np.log(2*np.pi)
    logp_test_mtx = -dist_u_test**2/(2*var_u_test)-dist_s_test**2/(2*var_s_test) \
                  - 0.5*np.log(var_u_test) - 0.5*np.log(var_s_test) - np.log(2*np.pi)
    mse_train_gene = mse_train_gene + np.mean(dist_u_train**2+dist_s_train**2, 0)
    mse_test_gene = mse_test_gene + np.mean(dist_u_test**2+dist_s_test**2, 0)
    mae_train_gene = mae_train_gene + np.mean(dist_u_train+dist_s_train, 0)
    mae_test_gene = mae_test_gene + np.mean(dist_u_test+dist_s_test, 0)
    ll_train_gene = ll_train_gene + logp_train_mtx.mean(0)
    ll_test_gene = ll_test_gene + logp_test_mtx.mean(0)

# %%
adata.var['pv_mse_train'] = mse_train_gene / n_sample
adata.var['pv_mse_test'] = mse_test_gene / n_sample
adata.var['pv_mae_train'] = mae_train_gene / n_sample
adata.var['pv_mae_test'] = mae_test_gene / n_sample
adata.var['pv_likelihood_train'] = ll_train_gene / n_sample
adata.var['pv_likelihood_test'] = ll_test_gene / n_sample
err_dic['MSE Train'] = mse_train / n_sample
err_dic['MSE Test'] = mse_test / n_sample
err_dic['MAE Train'] = mae_train / n_sample
err_dic['MAE Test'] = mae_test / n_sample
err_dic['LL Train'] = logp_train / n_sample
err_dic['LL Test'] = logp_test / n_sample
adata.uns['err'] = err_dic

# %%
err_dic
# Out:
# {'MSE Train': 9.284301726023356,
#  'MSE Test': 9.53989372253418,
#  'MAE Train': 0.3908252209424973,
#  'MAE Test': 0.3908365209897359,
#  'LL Train': 0.0,
#  'LL Test': 0.0}

# %% [markdown]
# ## Write to disk and plot results

# %%
data_path = f'{data_path_base}/pyro/continuous/{dataset}'
os.makedirs(data_path, exist_ok=True)
adata.write_h5ad(f'{data_path}/{dataset}.h5ad')

# %%
scv.pl.velocity_embedding_stream(adata,
                                 basis=embed,
                                 title='',
                                 vkey='pv_velocity',
                                 save=f'{figure_path}/pv_vel_stream_normal.png')
# Out:
# saving figure to file /scratch/blaauw_root/blaauw1/gyichen/figures/BMMC/pv_vel_stream_normal.png

# %%
scv.pl.scatter(adata, basis=embed, color='pv_time', color_map='plasma', dpi=100, save=f'{figure_path}/pv_time_normal.png')
# Out:
# saving figure to file /scratch/blaauw_root/blaauw1/gyichen/figures/BMMC/pv_time_normal.png
