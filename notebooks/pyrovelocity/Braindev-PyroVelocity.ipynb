# %%
import anndata
import scvelo as scv
import numpy as np
from scipy.stats import poisson
from pyrovelocity.api import train_model
from pyrovelocity.plot import plot_posterior_time, plot_gene_ranking,\
      vector_field_uncertainty, plot_vector_field_uncertain,\
      plot_mean_vector_field, project_grid_points,rainbowplot,denoised_umap,\
      us_rainbowplot, plot_arrow_examples
import os
import argparse
import time
import matplotlib.pyplot as plt
import torch
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Discrete Model
# ## 1. Data Preparation

# %%
dataset = 'Braindev'
root = '/scratch/blaauw_root/blaauw1/gyichen'
data_path_base = f'{root}/data'
adata = anndata.read_h5ad(f"{data_path_base}/{dataset}_pp.h5ad")
adata.layers['raw_spliced']   = adata.layers['spliced']
adata.layers['raw_unspliced'] = adata.layers['unspliced']
adata.obs['u_lib_size_raw'] = adata.layers['raw_unspliced'].toarray().sum(-1)
adata.obs['s_lib_size_raw'] = adata.layers['raw_spliced'].toarray().sum(-1)

# %% [markdown]
# ## 2. Train the model with a specific configuration

# %%
num_epochs = 4000
batch_size = -1
likelihood = 'Poisson'
input_type = 'raw'
train_size = 0.7

# %%
t_start = time.time()
pos_train, pos_test, train_idx, test_idx = train_model(adata,
                                                       max_epochs=num_epochs, 
                                                       svi_train=True, 
                                                       log_every=100,
                                                       patient_init=45,
                                                       batch_size=batch_size, 
                                                       use_gpu=0, 
                                                       likelihood=likelihood,
                                                       input_type=input_type,
                                                       cell_state='clusters',
                                                       include_prior=True,
                                                       offset=False,
                                                       library_size=True,
                                                       patient_improve=1e-3,
                                                       seed=2022,
                                                       guide_type='auto_t0_constraint',
                                                       train_size=train_size)
run_time = time.time()-t_start
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["raw_unspliced"]
# INFO     Using data from adata.layers["raw_spliced"]
# INFO     Successfully registered anndata object containing 29948 cells, 2000 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Please do not further modify adata until model is trained.
# Anndata setup with scvi-tools version 0.13.0.
#               Data Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃             Data             ┃ Count ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │            Cells             │ 29948 │
# │             Vars             │ 2000  │
# │            Labels            │   1   │
# │           Batches            │   1   │
# │           Proteins           │   0   │
# │ Extra Categorical Covariates │   0   │
# │ Extra Continuous Covariates  │   0   │
# └──────────────────────────────┴───────┘
#                  SCVI Data Registry
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃       Data       ┃      scvi-tools Location      ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        X         │  adata.layers['raw_spliced']  │
# │        U         │ adata.layers['raw_unspliced'] │
# │      batch       │   adata.obs['_scvi_batch']    │
# │      label       │   adata.obs['_scvi_labels']   │
# │      ind_x       │     adata.obs['_indices']     │
# │    u_lib_size    │    adata.obs['u_lib_size']    │
# │    s_lib_size    │    adata.obs['s_lib_size']    │
# │ u_lib_size_mean  │ adata.obs['u_lib_size_mean']  │
# │ s_lib_size_mean  │ adata.obs['s_lib_size_mean']  │
# │ u_lib_size_scale │ adata.obs['u_lib_size_scale'] │
# │ s_lib_size_scale │ adata.obs['s_lib_size_scale'] │
# └──────────────────┴───────────────────────────────┘
#                         Label Categories
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_labels'] │     0      │          0          │
# └───────────────────────────┴────────────┴─────────────────────┘
#                        Batch Categories
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃     Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_batch'] │     0      │          0          │
# └──────────────────────────┴────────────┴─────────────────────┘
# -----------
# auto
# auto_t0_constraint
# train_faster_with_batch
# step    1 loss = 3.73701e+08 patience = 45
# step  100 loss = 2.45171e+08 patience = 45
# step  200 loss = 1.99243e+08 patience = 45
# step  300 loss = 1.64801e+08 patience = 45
# step  400 loss = 1.34851e+08 patience = 45
# step  500 loss = 1.0941e+08 patience = 45
# step  600 loss = 8.84049e+07 patience = 45
# step  700 loss = 7.24081e+07 patience = 45
# step  800 loss = 6.2181e+07 patience = 45
# step  900 loss = 5.73311e+07 patience = 40
# step 1000 loss = 5.58419e+07 patience = 44
# step 1070 loss = 5.5336e+07 patience = 0
# train_faster_with_batch
# step    1 loss = 2.95574e+08 patience = 45
# step  100 loss = 2.50445e+08 patience = 45
# step  200 loss = 2.09467e+08 patience = 45
# step  300 loss = 1.79838e+08 patience = 45
# step  400 loss = 1.52823e+08 patience = 45
# step  500 loss = 1.28938e+08 patience = 45
# step  600 loss = 1.08929e+08 patience = 45
# step  700 loss = 9.48086e+07 patience = 45
# step  800 loss = 8.78667e+07 patience = 45
# step  900 loss = 8.54633e+07 patience = 43
# step 1000 loss = 8.52486e+07 patience = 44
# step 1100 loss = 8.50807e+07 patience = 44
# step 1200 loss = 8.51674e+07 patience = 44
# step 1300 loss = 8.51071e+07 patience = 45
# step 1400 loss = 8.52041e+07 patience = 43
# step 1500 loss = 8.52585e+07 patience = 42
# step 1600 loss = 8.52058e+07 patience = 45
# step 1700 loss = 8.52331e+07 patience = 45
# step 1800 loss = 8.51526e+07 patience = 44
# step 1900 loss = 8.51825e+07 patience = 44
# step 2000 loss = 8.50367e+07 patience = 44
# step 2100 loss = 8.51682e+07 patience = 45
# step 2200 loss = 8.51606e+07 patience = 45
# step 2300 loss = 8.51036e+07 patience = 45
# step 2400 loss = 8.53411e+07 patience = 45
# step 2500 loss = 8.52393e+07 patience = 45
# step 2600 loss = 8.50521e+07 patience = 45
# step 2700 loss = 8.52688e+07 patience = 45
# step 2800 loss = 8.52077e+07 patience = 44
# step 2900 loss = 8.5073e+07 patience = 44
# step 3000 loss = 8.50514e+07 patience = 45
# step 3100 loss = 8.53061e+07 patience = 44
# step 3200 loss = 8.51634e+07 patience = 43
# step 3300 loss = 8.52463e+07 patience = 42
# step 3400 loss = 8.53259e+07 patience = 45
# step 3500 loss = 8.50567e+07 patience = 45
# step 3600 loss = 8.5175e+07 patience = 44
# step 3700 loss = 8.49447e+07 patience = 45
# step 3800 loss = 8.51169e+07 patience = 45
# step 3900 loss = 8.50298e+07 patience = 45
# step 3999 loss = 8.52426e+07 patience = 43

# %% [markdown]
# ## 3. Save intermediate results
# We directly save the results because combining them would take too much memory.

# %%
data_path = f'{data_path_base}/pyro/discrete/{dataset}'
os.makedirs(data_path, exist_ok=True)
for key in pos_train:
    np.save(f'{data_path}/{dataset}_{key}_train.npy', pos_train[key])
del pos_train

# %%
os.makedirs(data_path, exist_ok=True)
for key in pos_test:
    np.save(f'{data_path}/{dataset}_{key}_test.npy', pos_test[key])
del pos_test

# %%
adata.uns['pv_train_idx'] = train_idx
adata.uns['pv_test_idx'] = test_idx
os.makedirs(data_path, exist_ok=True)
adata.write_h5ad(f'{data_path}/{dataset}.h5ad')
del adata

# %% [markdown]
# ## 4. Compute Velocity

# %%
dataset = 'Braindev'
root = '/scratch/blaauw_root/blaauw1/gyichen'
data_path_base = f'{root}/data'
data_path = f'{data_path_base}/pyro/discrete/{dataset}'
adata = anndata.read_h5ad(f'{data_path}/{dataset}.h5ad')

# %%
pos_train, pos_test = {}, {}
keys = ['alpha', 'beta', 'cell_gene_state', 'cell_time', 'dt_switching',
        'gamma', 's_inf', 's', 's_read_depth', 'st_norm', 'st', 'switching',
        't0', 'time_constraint', 'u_inf', 'u', 'u_read_depth', 'ut_norm', 'ut']
for key in keys:
    pos_train[key] = np.load(f'{data_path_base}/pyro/discrete/{dataset}/{dataset}_{key}_train.npy')
    pos_test[key] = np.load(f'{data_path_base}/pyro/discrete/{dataset}/{dataset}_{key}_test.npy')

# %%
train_idx = adata.uns['pv_train_idx']
test_idx = adata.uns['pv_test_idx']
pos = {}
for key in pos_train:
    n_sample = pos_train[key].shape[0]
    if(pos_train[key].shape[1]>1 and pos_train[key].shape[2]>1):
        val = np.zeros((n_sample, adata.n_obs, adata.n_vars))
        val[:,train_idx] = pos_train[key]
        val[:,test_idx] = pos_test[key]
        pos[key] = val
    elif(pos_train[key].shape[2]==1):
        val = np.zeros((n_sample, adata.n_obs, 1))
        val[:,train_idx] = pos_train[key]
        val[:,test_idx] = pos_test[key]
        pos[key] = val
    else:
        pos[key] = pos_train[key]

# %%
#Compute velocity
embed = "umap"
figure_path = f'{root}/figures/{dataset}'

fig, ax = plt.subplots(figsize=(8, 6))
embed_mean = plot_mean_vector_field(pos,
                                    adata,
                                    ax=ax,
                                    basis=embed,
                                    n_jobs=(adata.n_obs)//2000+1)
# Out:
# computing neighbors
#     finished (0:00:31) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocity graph (using 15/36 cores)
#   0%|          | 0/29948 [00:00<?, ?cells/s]
#     finished (0:02:11) --> added
#     'velocity_pyro_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:06) --> added
#     'velocity_pyro_umap', embedded velocity vectors (adata.obsm)

# %% [markdown]
# ## 5. Compute performance metrics and save results

# %%
def save_fitting(adata, pos_train, train_idx, pos_test=None, test_idx=None):
    split = not ((pos_test is None) or (test_idx is None))
    for key in pos_train:
        k,m,n = pos_train[key].shape
        if(m>1 and n>1):
            adata.layers[f'pv_{key}'] = np.zeros((adata.n_obs,n))
            adata.layers[f'pv_{key}'][train_idx] = pos_train[key].mean(0)
            if(split):
                adata.layers[f'pv_{key}'][test_idx] = pos_test[key].mean(0)
        elif(m>1):
            adata.obs[f'pv_{key}'] = np.zeros((adata.n_obs))
            adata.obs[f'pv_{key}'][train_idx] = pos_train[key].mean(0).squeeze()
            if(split):
                adata.obs[f'pv_{key}'][test_idx] = pos_test[key].mean(0).squeeze()
        elif(n>1):
            adata.var[f'pv_{key}'] = pos_train[key].mean(0).squeeze()
        else:
            adata.uns[f'pv_{key}'] = pos_train[key]

# %%
adata.obsm[f"pv_velocity_{embed}"] = embed_mean
del adata.obsm[f"velocity_pyro_{embed}"]
adata.layers["pv_shat"] = adata.layers["spliced_pyro"]
adata.layers["pv_uhat"] = np.zeros(adata.shape)
adata.layers["pv_uhat"][train_idx] = pos_train["u"].mean(0)
adata.layers["pv_uhat"][test_idx] = pos_test["u"].mean(0)
del adata.layers["spliced_pyro"]
adata.layers["pv_velocity"] = adata.layers["velocity_pyro"]
del adata.layers["velocity_pyro"]

adata.obs['pv_time'] = pos['cell_time'][:,:,0].mean(0).squeeze()
adata.uns['pv_train_idx'] = train_idx
adata.uns['pv_test_idx'] = test_idx
save_fitting(adata, pos_train, train_idx, pos_test, test_idx)

err_dic = {}
mse_train, mse_test, mae_train, mae_test, logp_train, logp_test = 0,0,0,0,0,0
mse_train_gene = np.ones((adata.n_vars))*np.nan
mse_test_gene = np.ones((adata.n_vars))*np.nan
mae_train_gene = np.ones((adata.n_vars))*np.nan
mae_test_gene = np.ones((adata.n_vars))*np.nan
ll_train_gene = np.ones((adata.n_vars))*np.nan
ll_test_gene = np.ones((adata.n_vars))*np.nan
for i in range(n_sample):
    dist_u_train = np.abs(adata.layers['raw_unspliced'][train_idx].A-pos_train['u'][i])
    dist_s_train = np.abs(adata.layers['raw_spliced'][train_idx].A-pos_train['s'][i])
    dist_u_test = np.abs(adata.layers['raw_unspliced'][test_idx].A-pos_test['u'][i])
    dist_s_test = np.abs(adata.layers['raw_spliced'][test_idx].A-pos_test['s'][i])
    mse_train += np.mean(dist_u_train**2+dist_s_train**2)
    mse_test += np.mean(dist_u_test**2+dist_s_test**2)
    mae_train += np.mean(dist_u_train+dist_s_train)
    mae_test += np.mean(dist_u_test+dist_s_test)
    logp_train += np.log(poisson.pmf(adata.layers['raw_unspliced'][train_idx].A, pos_train['ut'][i])+1e-10).sum(1).mean()\
                 +np.log(poisson.pmf(adata.layers['raw_spliced'][train_idx].A, pos_train['st'][i])+1e-10).sum(1).mean()
    logp_test += np.log(poisson.pmf(adata.layers['raw_unspliced'][test_idx].A, pos_test['ut'][i])+1e-10).sum(1).mean()\
                 +np.log(poisson.pmf(adata.layers['raw_spliced'][test_idx].A, pos_test['st'][i])+1e-10).sum(1).mean()
    mse_train_gene = mse_train_gene + np.mean(dist_u_train**2+dist_s_train**2, 0)
    mse_test_gene = mse_test_gene + np.mean(dist_u_test**2+dist_s_test**2, 0)
    mae_train_gene = mae_train_gene + np.mean(dist_u_train+dist_s_train, 0)
    mae_test_gene = mae_test_gene + np.mean(dist_u_test+dist_s_test, 0)
    ll_train_gene = ll_train_gene\
                  + np.log(poisson.pmf(adata.layers['raw_unspliced'][train_idx].A, pos_train['ut'][i])+1e-10).mean(0)\
                  + np.log(poisson.pmf(adata.layers['raw_spliced'][train_idx].A, pos_train['st'][i])+1e-10).mean(0)
    ll_test_gene = ll_test_gene\
                 + np.log(poisson.pmf(adata.layers['raw_unspliced'][test_idx].A, pos_test['ut'][i])+1e-10).mean(0)\
                 + np.log(poisson.pmf(adata.layers['raw_spliced'][test_idx].A, pos_test['st'][i])+1e-10).mean(0)

# %%
adata.var['pv_mse_train'] = mse_train_gene / n_sample
adata.var['pv_mse_test'] = mse_test_gene / n_sample
adata.var['pv_mae_train'] = mae_train_gene / n_sample
adata.var['pv_mae_test'] = mae_test_gene / n_sample
adata.var['pv_likelihood_train'] = ll_train_gene / n_sample
adata.var['pv_likelihood_test'] = ll_test_gene / n_sample
err_dic['MSE Train'] = mse_train / n_sample
err_dic['MSE Test'] = mse_test / n_sample
err_dic['MAE Train'] = mae_train / n_sample
err_dic['MAE Test'] = mae_test / n_sample
err_dic['LL Train'] = logp_train / n_sample
err_dic['LL Test'] = logp_test / n_sample
adata.uns['err'] = err_dic

# %%
err_dic

# %% [markdown]
# ## Write to disk and plot results

# %%
data_path = f'{data_path_base}/pyro/discrete/{dataset}'
os.makedirs(data_path, exist_ok=True)
adata.write_h5ad(f'{data_path}/{dataset}.h5ad')

# %%
from pyrovelocity.utils import mae_evaluate
out = mae_evaluate((pos_train, pos_test, train_idx, test_idx), adata)
# Out:
#                     MAE
# label
# Poisson train  0.284852
# Poisson valid  0.387666

# %%
scv.pl.velocity_embedding_stream(adata,
                                 basis=embed,
                                 title='',
                                 vkey='pv_velocity',
                                 save=f'{figure_path}/pv_vel_stream.png')
# Out:
# saving figure to file /scratch/blaauw_root/blaauw1/gyichen/figures/Braindev/pv_vel_stream.png

# %%
scv.pl.scatter(adata, basis=embed, color='pv_time', color_map='plasma', dpi=100, save=f'{figure_path}/pv_time.png')
# Out:
# saving figure to file /scratch/blaauw_root/blaauw1/gyichen/figures/Braindev/pv_time.png

# %% [markdown]
# # Continuous Model
# ## 1. Prepare Data

# %%
dataset = 'Braindev'
root = '/scratch/blaauw_root/blaauw1/gyichen'
data_path_base = f'{root}/data'
adata = anndata.read_h5ad(f"{data_path_base}/{dataset}_pp.h5ad")

# %% [markdown]
# ## 2. Train the model with a specific configuration

# %%
num_epochs = 4000
batch_size = -1
likelihood = 'Normal'
input_type = 'knn'
train_size = 0.7

# %%
t_start = time.time()
pos_train, pos_test, train_idx, test_idx = train_model(adata,
                                                       max_epochs=num_epochs, 
                                                       svi_train=True, 
                                                       log_every=100,
                                                       patient_init=45,
                                                       batch_size=batch_size, 
                                                       use_gpu=0, 
                                                       likelihood=likelihood,
                                                       input_type=input_type,
                                                       cell_state='clusters',
                                                       include_prior=True,
                                                       offset=False,
                                                       library_size=True,
                                                       patient_improve=1e-3,
                                                       seed=2022,
                                                       guide_type='auto_t0_constraint',
                                                       train_size=train_size)
run_time = time.time()-t_start
# Out:
# INFO     No batch_key inputted, assuming all cells are same batch
# INFO     No label_key inputted, assuming all cells have same label
# INFO     Using data from adata.layers["Mu"]
# INFO     Using data from adata.layers["Ms"]
# INFO     Successfully registered anndata object containing 29948 cells, 2000 vars, 1 batches, 1 labels, and 0
#          proteins. Also registered 0 extra categorical covariates and 0 extra continuous covariates.
# INFO     Please do not further modify adata until model is trained.
# Anndata setup with scvi-tools version 0.13.0.
#               Data Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃             Data             ┃ Count ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │            Cells             │ 29948 │
# │             Vars             │ 2000  │
# │            Labels            │   1   │
# │           Batches            │   1   │
# │           Proteins           │   0   │
# │ Extra Categorical Covariates │   0   │
# │ Extra Continuous Covariates  │   0   │
# └──────────────────────────────┴───────┘
#                  SCVI Data Registry
# ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃       Data       ┃      scvi-tools Location      ┃
# ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        X         │      adata.layers['Ms']       │
# │        U         │      adata.layers['Mu']       │
# │      batch       │   adata.obs['_scvi_batch']    │
# │      label       │   adata.obs['_scvi_labels']   │
# │      ind_x       │     adata.obs['_indices']     │
# │    u_lib_size    │    adata.obs['u_lib_size']    │
# │    s_lib_size    │    adata.obs['s_lib_size']    │
# │ u_lib_size_mean  │ adata.obs['u_lib_size_mean']  │
# │ s_lib_size_mean  │ adata.obs['s_lib_size_mean']  │
# │ u_lib_size_scale │ adata.obs['u_lib_size_scale'] │
# │ s_lib_size_scale │ adata.obs['s_lib_size_scale'] │
# └──────────────────┴───────────────────────────────┘
#                         Label Categories
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_labels'] │     0      │          0          │
# └───────────────────────────┴────────────┴─────────────────────┘
#                        Batch Categories
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃     Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_batch'] │     0      │          0          │
# └──────────────────────────┴────────────┴─────────────────────┘
# -----------
# auto
# auto_t0_constraint
# train_faster_with_batch
# step    1 loss = 3.77771e+08 patience = 45
# step  100 loss = 7.24239e+07 patience = 45
# step  200 loss = -3.07432e+07 patience = 44
# step  300 loss = -8.23898e+07 patience = 45
# step  400 loss = -1.11029e+08 patience = 45
# step  500 loss = -1.21572e+08 patience = 45
# step  600 loss = -1.26446e+08 patience = 44
# step  700 loss = -1.26655e+08 patience = 45
# step  800 loss = -1.28121e+08 patience = 43
# step  900 loss = -1.26449e+08 patience = 45
# step 1000 loss = -1.28478e+08 patience = 45
# step 1100 loss = -1.29031e+08 patience = 45
# step 1200 loss = -1.29946e+08 patience = 45
# step 1300 loss = -1.30963e+08 patience = 45
# step 1400 loss = -1.32043e+08 patience = 45
# step 1500 loss = -1.33288e+08 patience = 45
# step 1600 loss = -1.34411e+08 patience = 45
# step 1700 loss = -1.35579e+08 patience = 45
# step 1800 loss = -1.36496e+08 patience = 45
# step 1900 loss = -1.3736e+08 patience = 45
# step 2000 loss = -1.38184e+08 patience = 45
# step 2100 loss = -1.38955e+08 patience = 45
# step 2200 loss = -1.39535e+08 patience = 45
# step 2300 loss = -1.40066e+08 patience = 45
# step 2400 loss = -1.40576e+08 patience = 45
# step 2500 loss = -1.40975e+08 patience = 45
# step 2600 loss = -1.41414e+08 patience = 45
# step 2700 loss = -1.41794e+08 patience = 45
# step 2800 loss = -1.42121e+08 patience = 45
# step 2900 loss = -1.42359e+08 patience = 45
# step 3000 loss = -1.42701e+08 patience = 45
# step 3100 loss = -1.42902e+08 patience = 45
# step 3200 loss = -1.4307e+08 patience = 45
# step 3300 loss = -1.43362e+08 patience = 45
# step 3400 loss = -1.43551e+08 patience = 45
# step 3500 loss = -1.43653e+08 patience = 45
# step 3600 loss = -1.43894e+08 patience = 45
# step 3700 loss = -1.43999e+08 patience = 45
# step 3800 loss = -1.44166e+08 patience = 45
# step 3900 loss = -1.44282e+08 patience = 45
# step 3999 loss = -1.44406e+08 patience = 45
# train_faster_with_batch
# step    1 loss = 2.76281e+14 patience = 45
# step  100 loss = 3.19395e+14 patience = 45
# step  200 loss = 2.53861e+14 patience = 45
# step  300 loss = 2.19248e+14 patience = 44
# step  400 loss = 2.86073e+14 patience = 44
# step  500 loss = 2.2811e+14 patience = 44
# step  600 loss = 2.66361e+14 patience = 44
# step  700 loss = 2.63057e+14 patience = 44
# step  800 loss = 2.23071e+14 patience = 45
# step  900 loss = 2.82861e+14 patience = 45
# step 1000 loss = 3.76289e+14 patience = 44
# step 1100 loss = 2.36655e+14 patience = 45
# step 1200 loss = 3.04728e+14 patience = 44
# step 1300 loss = 2.07857e+14 patience = 45
# step 1400 loss = 2.71425e+14 patience = 45
# step 1500 loss = 2.49817e+14 patience = 42
# step 1600 loss = 2.10133e+14 patience = 44
# step 1700 loss = 2.59809e+14 patience = 44
# step 1800 loss = 2.91905e+14 patience = 43
# step 1900 loss = 2.52898e+14 patience = 43
# step 2000 loss = 1.70216e+14 patience = 45
# step 2100 loss = 3.02743e+14 patience = 41
# step 2200 loss = 2.3083e+14 patience = 45
# step 2300 loss = 2.80733e+14 patience = 45
# step 2400 loss = 2.85237e+14 patience = 43
# step 2500 loss = 2.46579e+14 patience = 45
# step 2600 loss = 3.34816e+14 patience = 45
# step 2700 loss = 3.76445e+14 patience = 45
# step 2800 loss = 2.25625e+14 patience = 44
# step 2900 loss = 2.01015e+14 patience = 44
# step 3000 loss = 2.03801e+14 patience = 45
# step 3100 loss = 3.24351e+14 patience = 45
# step 3200 loss = 3.07031e+14 patience = 45
# step 3300 loss = 2.4051e+14 patience = 45
# step 3400 loss = 2.39287e+14 patience = 45
# step 3500 loss = 3.10555e+14 patience = 45
# step 3600 loss = 2.37093e+14 patience = 45
# step 3700 loss = 2.22949e+14 patience = 45
# step 3800 loss = 1.98603e+14 patience = 44
# step 3900 loss = 2.21746e+14 patience = 45
# step 3999 loss = 2.22875e+14 patience = 45

# %% [markdown]
# ## 3. Save intermediate results

# %%
data_path = f'{data_path_base}/pyro/continuous/{dataset}'
os.makedirs(data_path, exist_ok=True)
for key in pos_train:
    np.save(f'{data_path}/{dataset}_{key}_train.npy', pos_train[key])
del pos_train

# %%
os.makedirs(data_path, exist_ok=True)
for key in pos_test:
    np.save(f'{data_path}/{dataset}_{key}_test.npy', pos_test[key])
del pos_test

# %%
adata.uns['pv_train_idx'] = train_idx
adata.uns['pv_test_idx'] = test_idx
os.makedirs(data_path, exist_ok=True)
adata.write_h5ad(f'{data_path}/{dataset}.h5ad')
del adata

# %% [markdown]
# ## 4. Compute Velocity

# %%
dataset = 'Braindev'
root = '/scratch/blaauw_root/blaauw1/gyichen'
data_path_base = f'{root}/data'
data_path = f'{data_path_base}/pyro/continuous/{dataset}'
adata = anndata.read_h5ad(f'{data_path}/{dataset}.h5ad')

# %%
pos_train, pos_test = {}, {}
keys = ['alpha', 'beta', 'cell_gene_state', 'cell_time', 'dt_switching',
        'gamma', 's_inf', 's_scale', 's', 'switching',
        't0', 'time_constraint', 'u_inf', 'u_scale', 'u']
for key in keys:
    pos_train[key] = np.load(f'{data_path_base}/pyro/continuous/{dataset}/{dataset}_{key}_train.npy')
    pos_test[key] = np.load(f'{data_path_base}/pyro/continuous/{dataset}/{dataset}_{key}_test.npy')

# %%
train_idx = adata.uns['pv_train_idx']
test_idx = adata.uns['pv_test_idx']
pos = {}
for key in pos_train:
    n_sample = pos_train[key].shape[0]
    if(pos_train[key].shape[1]>1 and pos_train[key].shape[2]>1):
        val = np.zeros((n_sample, adata.n_obs, adata.n_vars))
        val[:,train_idx] = pos_train[key]
        val[:,test_idx] = pos_test[key]
        pos[key] = val
    elif(pos_train[key].shape[2]==1):
        val = np.zeros((n_sample, adata.n_obs, 1))
        val[:,train_idx] = pos_train[key]
        val[:,test_idx] = pos_test[key]
        pos[key] = val
    else:
        pos[key] = pos_train[key]

# %%
pos['ut'] = pos['u'] * pos["u_scale"]
pos['st'] = pos['s']

# %%
#Compute velocity
embed = "umap"
figure_path = f'{root}/figures/{dataset}'

fig, ax = plt.subplots(figsize=(8, 6))
embed_mean = plot_mean_vector_field(pos,
                                    adata,
                                    ax=ax,
                                    basis=embed,
                                    n_jobs=(adata.n_obs)//2000+1)
# Out:
# computing neighbors
#     finished (0:00:24) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing velocity graph (using 15/36 cores)
#   0%|          | 0/29948 [00:00<?, ?cells/s]
#     finished (0:02:11) --> added
#     'velocity_pyro_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:05) --> added
#     'velocity_pyro_umap', embedded velocity vectors (adata.obsm)

# %% [markdown]
# ## 5. Compute performance metrics and save results

# %%
def save_fitting(adata, pos_train, train_idx, pos_test=None, test_idx=None):
    split = not ((pos_test is None) or (test_idx is None))
    for key in pos_train:
        k,m,n = pos_train[key].shape
        if(m>1 and n>1):
            adata.layers[f'pv_{key}'] = np.zeros((adata.n_obs,n))
            adata.layers[f'pv_{key}'][train_idx] = pos_train[key].mean(0)
            if(split):
                adata.layers[f'pv_{key}'][test_idx] = pos_test[key].mean(0)
        elif(m>1):
            adata.obs[f'pv_{key}'] = np.zeros((adata.n_obs))
            adata.obs[f'pv_{key}'][train_idx] = pos_train[key].mean(0).squeeze()
            if(split):
                adata.obs[f'pv_{key}'][test_idx] = pos_test[key].mean(0).squeeze()
        elif(n>1):
            adata.var[f'pv_{key}'] = pos_train[key].mean(0).squeeze()
        else:
            adata.uns[f'pv_{key}'] = pos_train[key]

# %%
adata.obsm[f"pv_velocity_{embed}"] = embed_mean
del adata.obsm[f"velocity_pyro_{embed}"]
adata.layers["pv_shat"] = adata.layers["spliced_pyro"]
adata.layers["pv_uhat"] = np.zeros(adata.shape)
adata.layers["pv_uhat"][train_idx] = pos_train["u"].mean(0)
adata.layers["pv_uhat"][test_idx] = pos_test["u"].mean(0)
del adata.layers["spliced_pyro"]
adata.layers["pv_velocity"] = adata.layers["velocity_pyro"]
del adata.layers["velocity_pyro"]

adata.obs['pv_time'] = pos['cell_time'][:,:,0].mean(0).squeeze()
adata.uns['pv_train_idx'] = train_idx
adata.uns['pv_test_idx'] = test_idx
save_fitting(adata, pos_train, train_idx, pos_test, test_idx)

err_dic = {}
mse_train, mse_test, mae_train, mae_test, logp_train, logp_test = 0,0,0,0,0,0
mse_train_gene = np.ones((adata.n_vars))*np.nan
mse_test_gene = np.ones((adata.n_vars))*np.nan
mae_train_gene = np.ones((adata.n_vars))*np.nan
mae_test_gene = np.ones((adata.n_vars))*np.nan
ll_train_gene = np.ones((adata.n_vars))*np.nan
ll_test_gene = np.ones((adata.n_vars))*np.nan
for i in range(pos['u'].shape[0]):
    dist_u_train = np.abs(adata.layers['Mu'][train_idx]-pos_train['u'][i])
    dist_s_train = np.abs(adata.layers['Ms'][train_idx]-pos_train['s'][i])
    dist_u_test = np.abs(adata.layers['Mu'][test_idx]-pos_test['u'][i])
    dist_s_test = np.abs(adata.layers['Ms'][test_idx]-pos_test['s'][i])
    mse_train += np.mean(dist_u_train**2+dist_s_train**2)
    mse_test += np.mean(dist_u_test**2+dist_s_test**2)
    mae_train += np.mean(dist_u_train+dist_s_train)
    mae_test += np.mean(dist_u_test+dist_s_test)
    #MLE of variance
    var_s_train, var_s_test = np.var(adata.layers['Mu'][train_idx]-pos_train['u'][i],0),np.var(adata.layers['Ms'][train_idx]-pos_train['s'][i],0)
    var_u_train, var_u_test = np.var(adata.layers['Mu'][test_idx]-pos_test['u'][i],0),np.var(adata.layers['Ms'][test_idx]-pos_test['s'][i],0)
    logp_train_mtx = -dist_u_train**2/(2*var_u_train)-dist_s_train**2/(2*var_s_train) \
                  - 0.5*np.log(var_u_train) - 0.5*np.log(var_s_train) - np.log(2*np.pi)
    logp_test_mtx = -dist_u_test**2/(2*var_u_test)-dist_s_test**2/(2*var_s_test) \
                  - 0.5*np.log(var_u_test) - 0.5*np.log(var_s_test) - np.log(2*np.pi)
    mse_train_gene = mse_train_gene + np.mean(dist_u_train**2+dist_s_train**2, 0)
    mse_test_gene = mse_test_gene + np.mean(dist_u_test**2+dist_s_test**2, 0)
    mae_train_gene = mae_train_gene + np.mean(dist_u_train+dist_s_train, 0)
    mae_test_gene = mae_test_gene + np.mean(dist_u_test+dist_s_test, 0)
    ll_train_gene = ll_train_gene + logp_train_mtx.mean(0)
    ll_test_gene = ll_test_gene + logp_test_mtx.mean(0)

# %%
adata.var['pv_mse_train'] = mse_train_gene / n_sample
adata.var['pv_mse_test'] = mse_test_gene / n_sample
adata.var['pv_mae_train'] = mae_train_gene / n_sample
adata.var['pv_mae_test'] = mae_test_gene / n_sample
adata.var['pv_likelihood_train'] = ll_train_gene / n_sample
adata.var['pv_likelihood_test'] = ll_test_gene / n_sample
err_dic['MSE Train'] = mse_train / n_sample
err_dic['MSE Test'] = mse_test / n_sample
err_dic['MAE Train'] = mae_train / n_sample
err_dic['MAE Test'] = mae_test / n_sample
err_dic['LL Train'] = logp_train / n_sample
err_dic['LL Test'] = logp_test / n_sample
adata.uns['err'] = err_dic

# %%
err_dic
# Out:
# {'MSE Train': 4.0648186524709065,
#  'MSE Test': 11.264509614308675,
#  'MAE Train': 0.46254030664761864,
#  'MAE Test': 0.9415288984775543,
#  'LL Train': 0.0,
#  'LL Test': 0.0}

# %% [markdown]
# ## Write to disk and plot results

# %%
data_path = f'{data_path_base}/pyro/continuous/{dataset}'
os.makedirs(data_path, exist_ok=True)
adata.write_h5ad(f'{data_path}/{dataset}.h5ad')

# %%
scv.pl.velocity_embedding_stream(adata,
                                 basis=embed,
                                 title='',
                                 vkey='pv_velocity',
                                 save=f'{figure_path}/pv_vel_stream_normal.png')
# Out:
# saving figure to file /scratch/blaauw_root/blaauw1/gyichen/figures/Braindev/pv_vel_stream_normal.png

# %%
scv.pl.scatter(adata, basis=embed, color='pv_time', color_map='plasma', dpi=100, save=f'{figure_path}/pv_time_normal.png')
# Out:
# saving figure to file /scratch/blaauw_root/blaauw1/gyichen/figures/Braindev/pv_time_normal.png
