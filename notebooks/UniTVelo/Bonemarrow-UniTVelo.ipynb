# %%
import unitvelo as utv
import anndata
import scvelo as scv
import numpy as np
import os
import argparse
import time
# Out:
# (Running UniTVelo 0.2.5.2)
# 2023-04-13 23:02:09

# %%
root = "/scratch/blaauw_root/blaauw1/gyichen"
dataset = "Bonemarrow"
adata = anndata.read_h5ad(f"{root}/data/{dataset}_pp.h5ad")

# %%
# Hyperparameters
velo_config = utv.config.Configuration()
velo_config.R2_ADJUST = False
velo_config.IROOT = 'HSC_1'
velo_config.FIT_OPTION = '1'
velo_config.ASSIGN_POS_U = True
velo_config.GPU = 0

# %%
t_start = time.time()
label = 'clusters'
adata = utv.run_model(adata, label, config_file=velo_config)
run_time = time.time() - t_start
print(f"Total run time: {run_time}")
# Out:
# ------> Manully Specified Parameters <------
# ASSIGN_POS_U:	True
# R2_ADJUST:	False
# IROOT:	HSC_1
# ------> Model Configuration Settings <------
# N_TOP_GENES:	2000
# LEARNING_RATE:	0.01
# FIT_OPTION:	1
# DENSITY:	SVD
# REORDER_CELL:	Soft_Reorder
# AGGREGATE_T:	True
# GENE_PRIOR:	None
# VGENES:	basic
# --------------------------------------------
#
# Current working dir is /home/gyichen/velovae/notebooks/UniTVelo.
# Results will be stored in res folder
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# Normalized count data: spliced, unspliced.
# Extracted 2000 highly variable genes.
# WARNING: Did not modify X as it looks preprocessed already.
# Extracted 2000 highly variable genes.
# Computing moments for 2000 genes with n_neighbors: 30 and n_pcs: 30
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
#
# # of velocity genes 520 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 520 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 520 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Use diffusion pseudotime as initial.
# Loss (Total): 5688.169, (Spliced): 2933.516, (Unspliced): 2754.653:   7%|▋         | 799/12000 [01:08<16:06, 11.59it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 5394.440, (Spliced): 2701.035, (Unspliced): 2693.405:  13%|█▎        | 1598/12000 [01:51<08:24, 20.63it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 5247.134, (Spliced): 2611.704, (Unspliced): 2635.430:  20%|█▉        | 2399/12000 [02:32<07:46, 20.58it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 5118.065, (Spliced): 2500.863, (Unspliced): 2617.203:  27%|██▋       | 3200/12000 [03:13<07:03, 20.77it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4983.105, (Spliced): 2377.258, (Unspliced): 2605.846:  33%|███▎      | 3998/12000 [03:54<06:25, 20.74it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4827.806, (Spliced): 2280.801, (Unspliced): 2547.004:  40%|███▉      | 4799/12000 [04:35<05:49, 20.63it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4687.797, (Spliced): 2242.189, (Unspliced): 2445.608:  47%|████▋     | 5600/12000 [05:16<05:23, 19.78it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4569.590, (Spliced): 2225.047, (Unspliced): 2344.543:  53%|█████▎    | 6400/12000 [06:00<04:43, 19.73it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4577.293, (Spliced): 2244.073, (Unspliced): 2333.220:  60%|██████    | 7200/12000 [06:43<04:02, 19.76it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4446.756, (Spliced): 2190.805, (Unspliced): 2255.951:  67%|██████▋   | 8000/12000 [07:27<03:26, 19.38it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4283.046, (Spliced): 2135.065, (Unspliced): 2147.981:  73%|███████▎  | 8800/12000 [08:11<02:42, 19.66it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4218.348, (Spliced): 2094.759, (Unspliced): 2123.589:  80%|████████  | 9600/12000 [08:56<02:03, 19.51it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4218.200, (Spliced): 2094.460, (Unspliced): 2123.739:  87%|████████▋ | 10400/12000 [09:40<01:21, 19.54it/s]
# MCOLN2
# DNM3
# PALD1
# FAT3
# PDZRN4
# PCED1B
# SLC8A3
# GDPD1
# PIEZO2
# SCN3A
# SNED1
# FGD5
# CRYBG3
# CD96
# EFCC1
# SH3TC1
# HHIP
# COL23A1
# RP11-113I22.1
# CRHBP
# THSD7A
# CNTNAP2
# CSGALNACT1
# FREM1
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4290.413, (Spliced): 2161.681, (Unspliced): 2128.732:  93%|█████████▎| 11200/12000 [10:32<00:54, 14.71it/s]
# MCOLN2
# GBP2
# SELP
# SELL
# PRDM16
# DNM3
# PALD1
# ROBO4
# SPON1
# FAT3
# CLEC9A
# PDZRN4
# PCED1B
# SRGAP1
# FOXO1
# PCDH9
# CCDC175
# SLC8A3
# HDC
# SKAP1
# HLF
# GDPD1
# PIEZO2
# RAB27B
# ST6GAL2
# TMEM163
# SCN3A
# RASGRP3
# LINC01122
# SNED1
# AJ006998.2
# FGD5
# CRYBG3
# CD96
# PHLDB2
# EFCC1
# CLNK
# PRKG2
# EMCN
# INPP4B
# SH3TC1
# LIMCH1
# GPAT3
# HHIP
# GUCY1A3
# MYO10
# COL23A1
# RP11-113I22.1
# ITGA2
# CRHBP
# ADGRG6
# THSD7A
# HOXA3
# CALN1
# ABCB1
# TRBC2
# CNTNAP2
# CSGALNACT1
# ANGPT1
# PREX2
# FREM1
# COL5A1
# ARHGAP6
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4259.986, (Spliced): 2115.821, (Unspliced): 2144.165: 100%|█████████▉| 11998/12000 [11:30<00:00, 14.64it/s]
# MCOLN2
# GBP2
# SELP
# SELL
# PRDM16
# DNM3
# PALD1
# ROBO4
# SPON1
# MDK
# FAT3
# VWF
# CLEC9A
# PDZRN4
# PCED1B
# SRGAP1
# LINC00426
# FOXO1
# PCDH9
# STXBP6
# CCDC175
# SLC8A3
# HDC
# SKAP1
# HLF
# GDPD1
# PIEZO2
# RAB27B
# AC004791.2
# ST6GAL2
# TMEM163
# SCN3A
# RASGRP3
# LINC01122
# SNED1
# AJ006998.2
# UMODL1
# FGD5
# CRYBG3
# CD96
# PHLDB2
# EFCC1
# EPHB1
# CLNK
# PRKG2
# EMCN
# INPP4B
# MARCH1
# SH3TC1
# LIMCH1
# GPAT3
# HHIP
# GUCY1A3
# MYO10
# COL23A1
# RP11-113I22.1
# IL7R
# ITGA2
# CRHBP
# RUNX2
# ADGRG6
# THSD7A
# HOXA3
# CALN1
# ABCB1
# PLXNA4
# TRBC2
# CNTNAP2
# CSGALNACT1
# ANGPT1
# PREX2
# FREM1
# PAX5
# COL5A1
# ARHGAP6
# FGF13
# CSF2RA
# AFF2
# Loss (Total): 4259.986, (Spliced): 2115.821, (Unspliced): 2144.165: 100%|█████████▉| 11999/12000 [11:59<00:00, 16.68it/s]
# Total loss 4218.200, vgene loss 4259.986
#   0%|          | 0/5028 [00:00<?, ?cells/s]
# Total run time: 737.1726133823395

# %%
scv.pl.velocity_embedding_stream(adata,
                                 color=adata.uns['label'],
                                 title='',
                                 basis='tsne',
                                 legend_loc='far right',
                                 dpi=100)
scv.tl.latent_time(adata, min_likelihood=None)

# %%
adata.obs['utv_time'] = adata.obs['latent_time'].to_numpy()
adata.uns['utv_run_time'] = run_time
scv.pl.scatter(adata, color="latent_time", basis='tsne', cmap="plasma")
adata.write_h5ad(f'{root}/data/utv/{dataset}/{dataset}.h5ad')
# Out:
# /scratch/blaauw_root/blaauw1/gyichen/utv_env/lib/python3.9/site-packages/scvelo/plotting/utils.py:869: MatplotlibDeprecationWarning: The draw_all function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use fig.draw_without_rendering() instead.
#   cb.draw_all()
