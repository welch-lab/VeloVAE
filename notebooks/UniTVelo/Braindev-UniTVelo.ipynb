# %%
import unitvelo as utv
import anndata
import scvelo as scv
import numpy as np
import os
import argparse
import time
# Out:
# (Running UniTVelo 0.2.5.2)
# 2023-04-18 19:11:08

# %%
root = "/scratch/blaauw_root/blaauw1/gyichen"
dataset = "Braindev"
adata = anndata.read_h5ad(f"{root}/data/{dataset}_pp.h5ad")

# %%
# Hyperparameters
velo_config = utv.config.Configuration()
velo_config.R2_ADJUST = True
velo_config.IROOT = None
velo_config.FIT_OPTION = '1'
velo_config.ASSIGN_POS_U = True
velo_config.GPU = 0

# %%
t_start = time.time()
label = 'clusters'
adata = utv.run_model(adata, label, config_file=velo_config)
run_time = time.time() - t_start
print(f"Total run time: {run_time}")
# Out:
# ------> Manully Specified Parameters <------
# ASSIGN_POS_U:	True
# ------> Model Configuration Settings <------
# N_TOP_GENES:	2000
# LEARNING_RATE:	0.01
# FIT_OPTION:	1
# DENSITY:	SVD
# REORDER_CELL:	Soft_Reorder
# AGGREGATE_T:	True
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /home/gyichen/velovae/notebooks/UniTVelo.
# Results will be stored in res folder
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# Normalized count data: spliced, unspliced.
# Extracted 2000 highly variable genes.
# WARNING: Did not modify X as it looks preprocessed already.
# Extracted 2000 highly variable genes.
# Computing moments for 2000 genes with n_neighbors: 30 and n_pcs: 30
# computing moments based on connectivities
#     finished (0:00:03) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
#
# # of velocity genes 1285 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 1100 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 1099 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 96446.242, (Spliced): 39376.699, (Unspliced): 57069.543:   7%|▋         | 800/12000 [06:27<1:32:43,  2.01it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 93815.560, (Spliced): 41277.343, (Unspliced): 52538.217:  13%|█▎        | 1600/12000 [14:11<1:24:56,  2.04it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 90680.728, (Spliced): 39938.369, (Unspliced): 50742.359:  20%|██        | 2400/12000 [21:15<1:18:44,  2.03it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 89655.017, (Spliced): 39579.447, (Unspliced): 50075.571:  27%|██▋       | 3200/12000 [28:21<1:12:27,  2.02it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 89739.774, (Spliced): 40218.533, (Unspliced): 49521.241:  33%|███▎      | 4000/12000 [35:27<1:06:33,  2.00it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 89530.741, (Spliced): 40407.811, (Unspliced): 49122.930:  40%|████      | 4800/12000 [42:32<58:36,  2.05it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 88784.058, (Spliced): 40199.556, (Unspliced): 48584.502:  47%|████▋     | 5600/12000 [49:40<52:30,  2.03it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 87296.437, (Spliced): 39987.418, (Unspliced): 47309.019:  53%|█████▎    | 6400/12000 [56:54<46:50,  1.99it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 85568.761, (Spliced): 39443.327, (Unspliced): 46125.434:  60%|██████    | 7200/12000 [1:04:16<40:09,  1.99it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 84802.813, (Spliced): 39250.832, (Unspliced): 45551.982:  67%|██████▋   | 8000/12000 [1:11:37<33:40,  1.98it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 84382.446, (Spliced): 39187.960, (Unspliced): 45194.486:  73%|███████▎  | 8800/12000 [1:18:59<26:56,  1.98it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 84108.859, (Spliced): 39169.296, (Unspliced): 44939.563:  80%|████████  | 9600/12000 [1:26:21<20:08,  1.99it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 83866.100, (Spliced): 39167.774, (Unspliced): 44698.326:  87%|████████▋ | 10400/12000 [1:33:42<13:44,  1.94it/s]
# Colgalt2
# Atp2b3
# Dlx6os1
# Trhde
# Galr1
# Kcnh8
# Unc13c
# Rgs9
# Cyct
# Loss (Total): 84007.774, (Spliced): 39491.727, (Unspliced): 44516.047:  93%|█████████▎| 11200/12000 [1:42:33<09:39,  1.38it/s]
# Ctsc
# Slc13a4
# Hspb1
# P4ha3
# Cd36
# Acyp2
# Sfxn5
# Prelp
# Rfx4
# Wnt4
# Slc39a12
# 1700019D03Rik
# Lgr6
# Abcb9
# Cyp26b1
# Grm3
# Arhgap20
# Wnt1
# Zic4
# Igf1
# Grin3a
# Cpne8
# Afap1l2
# Cyp2j6
# Il33
# Slitrk2
# Col14a1
# Hs3st3a1
# Baalc
# Pde1b
# Creg2
# Pdlim3
# Ccdc190
# Ednrb
# Paqr8
# Nim1k
# Prss35
# Ppp1r3c
# Atp13a4
# Cybrd1
# Angptl1
# Pgm5
# Cbr3
# Etv4
# Acsbg1
# Fam212b
# Dbx2
# Hepacam
# Hsdl2
# Tlcd1
# Cyp2j9
# Fgfr3
# Folh1
# Cbs
# Egfr
# Mmp15
# Pcdh11x
# Nkx2-2
# Brinp3
# A930009A15Rik
# Fa2h
# Dbndd2
# Elovl7
# Itpr2
# Ugt8a
# Tmcc3
# Sox10
# Klf9
# 9630013A20Rik
# Kcnj10
# Tal2
# Chrna3
# Cav2
# Cdkn1a
# Neurod4
# Glra1
# Dll1
# Fstl4
# Isl1
# Plpp4
# Grem2
# Hoxb6
# Pid1
# Lhx9
# 2600014E21Rik
# Dlx6os1
# Kirrel2
# Angpt1
# Optc
# Barhl1
# Trhde
# Prox1
# Rxrg
# Npas1
# Gm27199
# Gad2
# Sall3
# Nxph1
# Nova1
# Galr1
# Aldh1a1
# Prr16
# Reln
# Neto1
# Kcnh8
# Gem
# Spock3
# Cbln4
# Gabrg1
# Unc13c
# Car8
# Vwc2
# Eepd1
# Lifr
# Dtna
# Pou6f2
# Synpr
# Col8a1
# Nell1
# Rgs9
# Ddit4l
# Stk32a
# Cyct
# BC051019
# Tcte1
# Lrrc71
# Abhd3
# Loss (Total): 108916.455, (Spliced): 53950.570, (Unspliced): 54965.885:  93%|█████████▎| 11201/12000 [1:45:51<07:33,  1.76it/s]
# Total loss 83688.692, vgene loss 108916.455
#   0%|          | 0/29948 [00:00<?, ?cells/s]
# Total run time: 6548.830854892731

# %%
scv.pl.velocity_embedding_stream(adata,
                                 color=adata.uns['label'],
                                 title='',
                                 basis='umap',
                                 legend_loc='far right',
                                 dpi=100)
scv.tl.latent_time(adata, min_likelihood=None)

# %%
adata.obs['utv_time'] = adata.obs['latent_time'].to_numpy()
adata.uns['utv_run_time'] = run_time
scv.pl.scatter(adata, color="latent_time", basis='umap', cmap="plasma")
adata.write_h5ad(f'{root}/data/utv/{dataset}/{dataset}.h5ad')
# Out:
# /scratch/blaauw_root/blaauw1/gyichen/utv_env/lib/python3.9/site-packages/scvelo/plotting/utils.py:869: MatplotlibDeprecationWarning: The draw_all function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use fig.draw_without_rendering() instead.
#   cb.draw_all()
