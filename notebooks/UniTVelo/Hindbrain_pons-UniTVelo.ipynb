# %%
import unitvelo as utv
import anndata
import scvelo as scv
import numpy as np
import os
import argparse
import time
# Out:
# (Running UniTVelo 0.2.5.2)
# 2023-04-13 23:25:48

# %%
root = "/scratch/blaauw_root/blaauw1/gyichen"
dataset = "Hindbrain_pons"
adata = anndata.read_h5ad(f"{root}/data/{dataset}_pp.h5ad")

# %%
# Hyperparameters
velo_config = utv.config.Configuration()
velo_config.R2_ADJUST = False
velo_config.IROOT = None
velo_config.FIT_OPTION = '1'
velo_config.GPU = 0

# %%
t_start = time.time()
label = 'clusters'
adata = utv.run_model(adata, label, config_file=velo_config)
run_time = time.time() - t_start
print(f"Total run time: {run_time}")
# Out:
# ------> Manully Specified Parameters <------
# ASSIGN_POS_U:	True
# ------> Model Configuration Settings <------
# N_TOP_GENES:	2000
# LEARNING_RATE:	0.01
# FIT_OPTION:	1
# DENSITY:	SVD
# REORDER_CELL:	Soft_Reorder
# AGGREGATE_T:	True
# R2_ADJUST:	True
# GENE_PRIOR:	None
# VGENES:	basic
# IROOT:	None
# --------------------------------------------
#
# Current working dir is /home/gyichen/velovae/notebooks/UniTVelo.
# Results will be stored in res folder
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# Normalized count data: spliced, unspliced.
# Extracted 2000 highly variable genes.
# WARNING: Did not modify X as it looks preprocessed already.
# Extracted 2000 highly variable genes.
# Computing moments for 2000 genes with n_neighbors: 30 and n_pcs: 30
# computing moments based on connectivities
#     finished (0:00:01) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
#
# # of velocity genes 727 (Criterion: positive regression coefficient between un/spliced counts)
# # of velocity genes 602 (Criterion: std of un/spliced reads should be moderate, w/o extreme values)
# # of velocity genes 602 (Criterion: genes have reads in more than 5% of total cells)
# Using GPU card: 0
# Loss (Total): 209968.884, (Spliced): 102034.625, (Unspliced): 107934.259:   7%|▋         | 800/12000 [01:24<19:51,  9.40it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 119359.688, (Spliced): 66321.708, (Unspliced): 53037.980:  13%|█▎        | 1600/12000 [02:56<18:38,  9.30it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 110560.558, (Spliced): 63842.472, (Unspliced): 46718.086:  20%|██        | 2400/12000 [04:26<16:59,  9.41it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 108528.498, (Spliced): 63316.744, (Unspliced): 45211.754:  27%|██▋       | 3199/12000 [05:17<08:53, 16.49it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 109574.857, (Spliced): 64016.080, (Unspliced): 45558.777:  33%|███▎      | 3999/12000 [06:09<07:53, 16.91it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 111436.771, (Spliced): 64812.664, (Unspliced): 46624.106:  40%|████      | 4800/12000 [06:58<07:02, 17.04it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 111173.551, (Spliced): 64883.701, (Unspliced): 46289.850:  47%|████▋     | 5600/12000 [07:49<06:19, 16.84it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 108948.595, (Spliced): 69844.757, (Unspliced): 39103.837:  53%|█████▎    | 6399/12000 [08:42<05:52, 15.90it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 102421.532, (Spliced): 67788.432, (Unspliced): 34633.100:  60%|█████▉    | 7199/12000 [09:37<05:03, 15.81it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 102581.409, (Spliced): 67785.947, (Unspliced): 34795.462:  67%|██████▋   | 8000/12000 [10:27<04:12, 15.85it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 101713.272, (Spliced): 67606.983, (Unspliced): 34106.289:  73%|███████▎  | 8800/12000 [11:23<03:21, 15.85it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 103781.887, (Spliced): 67831.734, (Unspliced): 35950.153:  80%|████████  | 9600/12000 [12:18<02:27, 16.26it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 104104.020, (Spliced): 67991.575, (Unspliced): 36112.445:  87%|████████▋ | 10400/12000 [13:13<01:41, 15.76it/s]
# Pcp4
# Prune2
# Cdh4
# Plekhn1
# Loss (Total): 108601.365, (Spliced): 69391.860, (Unspliced): 39209.505:  93%|█████████▎| 11200/12000 [14:16<01:06, 12.07it/s]
# Pid1
# Chst11
# Basp1
# Pcp4
# Zeb1
# Prune2
# Kcnip3
# Tshz2
# Cdh4
# Grin3a
# Plekhn1
# Ugdh
# Spon1
# Ntm
# Itga9
# Loss (Total): 118911.827, (Spliced): 73628.405, (Unspliced): 45283.422:  93%|█████████▎| 11200/12000 [14:21<01:06, 12.07it/s]
# Pid1
# Chst11
# Basp1
# Pcp4
# Zeb1
# Prune2
# Kcnip3
# Tshz2
# Cdh4
# Grin3a
# Plekhn1
# Ugdh
# Spon1
# Ntm
# Itga9
# Loss (Total): 118911.827, (Spliced): 73628.405, (Unspliced): 45283.422:  93%|█████████▎| 11201/12000 [14:58<01:04, 12.47it/s]
# Total loss 101713.272, vgene loss 118911.827
#   0%|          | 0/6253 [00:00<?, ?cells/s]
# Total run time: 924.9467539787292

# %%
scv.pl.velocity_embedding_stream(adata,
                                 color=adata.uns['label'],
                                 title='',
                                 legend_loc='far right',
                                 dpi=100)
scv.tl.latent_time(adata, min_likelihood=None)
scv.pl.scatter(adata, color="latent_time", cmap="plasma")
adata.obs['utv_time'] = adata.obs['latent_time'].to_numpy()

adata.uns['utv_run_time'] = run_time

adata.write_h5ad(f'{root}/data/utv/{dataset}/{dataset}.h5ad')
# Out:
# /scratch/blaauw_root/blaauw1/gyichen/utv_env/lib/python3.9/site-packages/scvelo/plotting/utils.py:869: MatplotlibDeprecationWarning: The draw_all function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use fig.draw_without_rendering() instead.
#   cb.draw_all()
